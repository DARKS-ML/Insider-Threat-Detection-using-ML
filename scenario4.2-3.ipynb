# %%
import pandas as pd
from modules import usermodules as um

# %%
file = '../dataset/answers/r4.2-3/'

# %%
df1 = pd.read_csv(file+'r4.2-3-BBS0039.csv',header=['vector','id','date','user','pc','activity',])
df1.head()
# Out:
#    email  {Z1N2-F1FA87YB-4221ITSF}  08/12/2010 10:24:05  BBS0039  PC-9436  \
# 0  email  {T2G4-S9UB53ZH-3260RWIL}  08/12/2010 10:39:01  FAW0032  PC-5866
# 1  email  {C2C7-S0RT56MV-5031DXJZ}  08/12/2010 11:26:15  BBS0039  PC-9436
# 2  email  {X1C6-P0XL81JW-3816ZGTD}  08/12/2010 12:30:14  FAW0032  PC-5866
# 3   http  {D2Z8-A8NQ04XG-4780RMTE}  08/12/2010 13:35:00  BBS0039  PC-9436
# 4   http  {X1X3-F5VP35FI-4528EQSM}  08/12/2010 13:42:15  BBS0039  PC-9436
#
#                       Frances.Alisa.Wiggins@dtaa.com  \
# 0                      Bevis.Brady.Sheppard@dtaa.com
# 1                     Frances.Alisa.Wiggins@dtaa.com
# 2                      Bevis.Brady.Sheppard@dtaa.com
# 3  http://www.spectorsoft.com/products/SpectorPro...
# 4  http://www.dailykeylogger.com/wetest/NNXrlybtt...
#
#                                           Unnamed: 6  Unnamed: 7  \
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# ...
