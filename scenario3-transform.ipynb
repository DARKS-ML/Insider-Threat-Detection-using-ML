# %% [markdown]
# # Session-1 for cleaning

# %%
# library section
import pandas as pd
import numpy as np
from modules import usermodules as um
# import matplotlib as mlb
# import matplotlib.pyplot as plt
# %matplotlib inline
# import seaborn as sns

# %%
file = '../dataset/r4.2/'

# %%
#first read all required dataframe
device = pd.read_csv(file+'device.csv')
print('Device Reading Done !')

logon = pd.read_csv(file+'logon.csv')
print('Logon Reading Done !')

email = pd.read_csv(file+'email.csv')
print('Email Reading Done !')

# %%
#make copy and remove id from dataframe 
df1 = device.copy()
df2 = df1.drop(['id'], axis=1)
print('Device id Removed')

df3 = logon.copy()
df4 = df3.drop(['id'], axis=1)
print('Logon id Droped')

df5 = email.copy()
df6 = df5.drop(['id'], axis=1)
print('Email id Drop')

# %%
#read file 
print(df2.head())
print(df4.head())
print(df6.head())

# %%
#convert to date time

print('Processing Device file')
um.convertToDateTime(df2,'date')
print('Device date is conveted to Datetime64')

print('Processing Logon file')
um.convertToDateTime(df4,'date')
print('Logon date is conveted to Datetime64')

print('Processing Email file')
um.convertToDateTime(df6,'date')
print('Email date is conveted to Datetime64')

# %%
#information about dataframe
print('Information about Device')
informationAboutDF(df2)
um.dividerLine()

print('Information about Logon')
informationAboutDF(df2)
um.dividerLine()

print('Information about Email')
um.informationAboutDF(df2)
um.dividerLine()

# %%
#export copy of datetime conveted file of each
um.exportFile(df2,'device')
um.exportFile(df4,'logon')
um.exportFile(df6,'email')

# %% [markdown]
# # Session-2 for other works

# %%
import pandas as pd
from modules import usermodules as um
file = '../dataset/r4.2/'

# %%
#read new file for further processing

print('Reading Device Dataframe')
device = pd.read_csv(file+'device_copy.csv')
print('Device Reading Done !')

print('Reading Logon Dataframe')
logon = pd.read_csv(file+'logon_copy.csv')
print('Logon Reading Done !')

print('Reading Email Dataframe')
email = pd.read_csv(file+'email_copy.csv')
print('Email Reading Done !')
# Out:
# Reading Device Dataframe
# Device Reading Done !
# Reading Logon Dataframe
# Logon Reading Done !
# Reading Email Dataframe
# Email Reading Done !

# %%
#Information About Dataframe
um.dividerLine('Device Info')
um.informationAboutDF(device)

um.dividerLine('Logon Info')
um.informationAboutDF(logon)

um.dividerLine('Email Info')
um.informationAboutDF(email)
# Out:
# ************************************
#
# Device Info
#
# ************************************
#
#
# ************************************
#
# Shape
#  (405380, 4)
#
#
# ************************************
#
# Null value Information
#  date        0
# user        0
# pc          0
# activity    0
# dtype: int64
#
#
# ************************************
#
# Dataframe Types
#  date        object
# user        object
# pc          object
# activity    object
# dtype: object
#
#
# ************************************
#
# Column Information
#  Index(['date', 'user', 'pc', 'activity'], dtype='object')
#
#
# ************************************
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405380 entries, 0 to 405379
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   date      405380 non-null  object
#  1   user      405380 non-null  object
#  2   pc        405380 non-null  object
# ...

# %%
#concating dataframes
df = pd.concat([device,logon,email])
#conver date int datetime
um.dividerLine('Information After Concatination')
um.informationAboutDF(df)
# Out:
# ************************************
#
# Information After Concatination
#
# ************************************
#
#
# ************************************
#
# Shape
#  (3890218, 11)
#
#
# ************************************
#
# Null value Information
#  date                 0
# user                 0
# pc                   0
# activity       2629979
# to             1260239
# cc             2877293
# bcc            3473216
# from           1260239
# size           1260239
# attachments    1260239
# content        1260239
# dtype: int64
#
#
# ************************************
#
# Dataframe Types
#  date            object
# user            object
# pc              object
# activity        object
# to              object
# cc              object
# bcc             object
# from            object
# size           float64
# attachments    float64
# content         object
# dtype: object
#
#
# ************************************
#
# Column Information
# ...

# %%
df['activity'] = df['activity'].fillna('email')
df.isnull().sum()
# Out:
# date                 0
# user                 0
# pc                   0
# activity             0
# to             1260239
# cc             2877293
# bcc            3473216
# from           1260239
# size           1260239
# attachments    1260239
# content        1260239
# dtype: int64

# %%
df.activity.unique()
# Out:
# array(['Connect', 'Disconnect', 'Logon', 'Logoff', 'email'], dtype=object)

# %%
#create Separate Column with respective Header
# x = df['activity']
# function = lambda x:'logon' if (x == 'Logon' or x =='Logoff') else('device' if (x=='Connect' or x== 'Disconnect') else 'email')
# df['vector'] = df['activity'].apply(function)
# df.head()

# %%
def assignHeaderAsvalue(x):
    if(x == 'Logon' or x =='Logoff'):
        x = 'logon'
        return x
    elif(x == 'Connect' or x =='Disconnect'):
        x ='device'
        return x
    else:
        x = 'email'
        return x

# %%
x = df['activity']
df['vector'] = x.apply(assignHeaderAsvalue)

# %%
df.head()
# Out:
#                   date     user       pc    activity   to   cc  bcc from  \
# 0  2010-01-02 07:21:06  MOH0273  PC-6699     Connect  NaN  NaN  NaN  NaN
# 1  2010-01-02 07:37:41  MOH0273  PC-6699  Disconnect  NaN  NaN  NaN  NaN
# 2  2010-01-02 07:59:11  HPH0075  PC-2417     Connect  NaN  NaN  NaN  NaN
# 3  2010-01-02 07:59:49  IIW0249  PC-0843     Connect  NaN  NaN  NaN  NaN
# 4  2010-01-02 08:04:26  IIW0249  PC-0843  Disconnect  NaN  NaN  NaN  NaN
#
#    size  attachments content  vector
# 0   NaN          NaN     NaN  device
# 1   NaN          NaN     NaN  device
# 2   NaN          NaN     NaN  device
# 3   NaN          NaN     NaN  device
# 4   NaN          NaN     NaN  device

# %%
#convertion level
df['date'] = pd.to_datetime(df['date'])
df['user'] = df['user'].astype('category')
df['pc'] = df['pc'].astype('category')
df['activity'] = df['activity'].astype('category')
um.dividerLine('Data Type after Convertion')
print(df.dtypes)
# Out:
# ************************************
#
# Data Type after Convertion
#
# ************************************
#
# date           datetime64[ns]
# user                 category
# pc                   category
# activity             category
# to                     object
# cc                     object
# bcc                    object
# from                   object
# size                  float64
# attachments           float64
# content                object
# vector                 object
# dtype: object

# %%
#sorting based in datetine
sorted_data = df.sort_values('date')
um.dividerLine('Data After Sorted')
print(sorted_data.head())
# Out:
# ************************************
#
# Data After Sorted
#
# ************************************
#
#                  date     user       pc activity   to   cc  bcc from  size  \
# 0 2010-01-02 06:49:00  NGF0157  PC-6056    Logon  NaN  NaN  NaN  NaN   NaN
# 1 2010-01-02 06:50:00  LRR0148  PC-4275    Logon  NaN  NaN  NaN  NaN   NaN
# 2 2010-01-02 06:53:04  LRR0148  PC-4124    Logon  NaN  NaN  NaN  NaN   NaN
# 4 2010-01-02 07:00:00  MOH0273  PC-6699    Logon  NaN  NaN  NaN  NaN   NaN
# 3 2010-01-02 07:00:00  IRM0931  PC-7188    Logon  NaN  NaN  NaN  NaN   NaN
#
#    attachments content vector
# 0          NaN     NaN  logon
# 1          NaN     NaN  logon
# 2          NaN     NaN  logon
# 4          NaN     NaN  logon
# 3          NaN     NaN  logon

# %%
df = sorted_data.copy()
df.head()
# Out:
#                  date     user       pc activity   to   cc  bcc from  size  \
# 0 2010-01-02 06:49:00  NGF0157  PC-6056    Logon  NaN  NaN  NaN  NaN   NaN
# 1 2010-01-02 06:50:00  LRR0148  PC-4275    Logon  NaN  NaN  NaN  NaN   NaN
# 2 2010-01-02 06:53:04  LRR0148  PC-4124    Logon  NaN  NaN  NaN  NaN   NaN
# 4 2010-01-02 07:00:00  MOH0273  PC-6699    Logon  NaN  NaN  NaN  NaN   NaN
# 3 2010-01-02 07:00:00  IRM0931  PC-7188    Logon  NaN  NaN  NaN  NaN   NaN
#
#    attachments content vector
# 0          NaN     NaN  logon
# 1          NaN     NaN  logon
# 2          NaN     NaN  logon
# 4          NaN     NaN  logon
# 3          NaN     NaN  logon

# %%
#create insiderthreat column 
df['insiderthreat'] = '🤔'
df.head()
# Out:
#                  date     user       pc activity   to   cc  bcc from  size  \
# 0 2010-01-02 06:49:00  NGF0157  PC-6056    Logon  NaN  NaN  NaN  NaN   NaN
# 1 2010-01-02 06:50:00  LRR0148  PC-4275    Logon  NaN  NaN  NaN  NaN   NaN
# 2 2010-01-02 06:53:04  LRR0148  PC-4124    Logon  NaN  NaN  NaN  NaN   NaN
# 4 2010-01-02 07:00:00  MOH0273  PC-6699    Logon  NaN  NaN  NaN  NaN   NaN
# 3 2010-01-02 07:00:00  IRM0931  PC-7188    Logon  NaN  NaN  NaN  NaN   NaN
#
#    attachments content vector insiderthreat
# 0          NaN     NaN  logon             🤔
# 1          NaN     NaN  logon             🤔
# 2          NaN     NaN  logon             🤔
# 4          NaN     NaN  logon             🤔
# 3          NaN     NaN  logon             🤔

# %%
df.vector.unique()
# Out:
# array(['logon', 'email', 'device'], dtype=object)

# %%
#Rearrange Column
arrange_column = ['insiderthreat','vector','date','user','pc','activity','to','from','cc','bcc','size','attachments','content']
df = df.reindex(columns=arrange_column)
df.head()
# Out:
#   insiderthreat vector                date     user       pc activity   to  \
# 0             🤔  logon 2010-01-02 06:49:00  NGF0157  PC-6056    Logon  NaN
# 1             🤔  logon 2010-01-02 06:50:00  LRR0148  PC-4275    Logon  NaN
# 2             🤔  logon 2010-01-02 06:53:04  LRR0148  PC-4124    Logon  NaN
# 4             🤔  logon 2010-01-02 07:00:00  MOH0273  PC-6699    Logon  NaN
# 3             🤔  logon 2010-01-02 07:00:00  IRM0931  PC-7188    Logon  NaN
#
#   from   cc  bcc  size  attachments content
# 0  NaN  NaN  NaN   NaN          NaN     NaN
# 1  NaN  NaN  NaN   NaN          NaN     NaN
# 2  NaN  NaN  NaN   NaN          NaN     NaN
# 4  NaN  NaN  NaN   NaN          NaN     NaN
# 3  NaN  NaN  NaN   NaN          NaN     NaN

# %%
print('Exporting Processing is Running ...')
um.exportFile(df,'scenario3-transform')
print('Done 😎 ')

# %%
df1 = pd.read_csv(file+'scenario3-transform_copy.csv')
df1.head()
# Out:
#   insiderthreat vector                 date     user       pc activity   to  \
# 0             🤔  logon  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  NaN
# 1             🤔  logon  2010-01-02 06:50:00  LRR0148  PC-4275    Logon  NaN
# 2             🤔  logon  2010-01-02 06:53:04  LRR0148  PC-4124    Logon  NaN
# 3             🤔  logon  2010-01-02 07:00:00  MOH0273  PC-6699    Logon  NaN
# 4             🤔  logon  2010-01-02 07:00:00  IRM0931  PC-7188    Logon  NaN
#
#   from   cc  bcc  size  attachments content
# 0  NaN  NaN  NaN   NaN          NaN     NaN
# 1  NaN  NaN  NaN   NaN          NaN     NaN
# 2  NaN  NaN  NaN   NaN          NaN     NaN
# 3  NaN  NaN  NaN   NaN          NaN     NaN
# 4  NaN  NaN  NaN   NaN          NaN     NaN

# %%
df.dtypes
# Out:
# insiderthreat            object
# vector                   object
# date             datetime64[ns]
# user                   category
# pc                     category
# activity               category
# to                       object
# from                     object
# cc                       object
# bcc                      object
# size                    float64
# attachments             float64
# content                  object
# dtype: object

# %% [markdown]
# '''
# #vector
# http = 0
# email = 1
# device = 2
# logon = 3
# '''

# %%
x = df['vector']
function = lambda x:3 if x == 'logon'  else(2 if x=='device'  else 1)
df['vector'] = df['vector'].apply(function)
df.head()

''' #vector http = 0 email = 1 device = 2 logon = 3 '''
# Out:
# ' #vector http = 0 email = 1 device = 2 logon = 3 '

# %%
um.informationAboutDF(df)
# Out:
# ************************************
#
# Shape
#  (3890218, 13)
#
#
# ************************************
#
# Null value Information
#  insiderthreat          0
# vector                 0
# date                   0
# user                   0
# pc                     0
# activity               0
# to               1260239
# from             1260239
# cc               2877293
# bcc              3473216
# size             1260239
# attachments      1260239
# content          1260239
# dtype: int64
#
#
# ************************************
#
# Dataframe Types
#  insiderthreat            object
# vector                    int64
# date             datetime64[ns]
# user                   category
# pc                     category
# activity               category
# to                       object
# from                     object
# cc                       object
# bcc                      object
# size                    float64
# attachments             float64
# ...

# %% [markdown]
# # Section-3 Choose Scenario 3 dataset from answer

# %%
import pandas as pd
from modules import usermodules as um

# %%
def readCSV(file_name):
    headerList = ['source','id','date','user','pc','from','1','2','to','3','4','content']
    return pd.read_csv(f'../dataset/answers/r4.2-3/{file_name}',names=headerList,usecols=[0,1,2,3,4])

# %%
print('Reading DataFrame .....')
df1 = readCSV('r4.2-3-BBS0039.csv')
df2 = readCSV('r4.2-3-BSS0369.csv')
df3 = readCSV('r4.2-3-CCA0046.csv')
df4 = readCSV('r4.2-3-CSC0217.csv')
df5 = readCSV('r4.2-3-GTD0219.csv')
df6 = readCSV('r4.2-3-JGT0221.csv')
df7 = readCSV('r4.2-3-JLM0364.csv')
df8 = readCSV('r4.2-3-JTM0223.csv')
df9 = readCSV('r4.2-3-MPM0220.csv')
df10 = readCSV('r4.2-3-MSO0222.csv')
print('Reading Done 😎')
# Out:
# Reading DataFrame .....
# Reading Done 😎

# %%
df1.head()
# Out:
#   source                        id                 date     user       pc
# 0  email  {Z1N2-F1FA87YB-4221ITSF}  08/12/2010 10:24:05  BBS0039  PC-9436
# 1  email  {T2G4-S9UB53ZH-3260RWIL}  08/12/2010 10:39:01  FAW0032  PC-5866
# 2  email  {C2C7-S0RT56MV-5031DXJZ}  08/12/2010 11:26:15  BBS0039  PC-9436
# 3  email  {X1C6-P0XL81JW-3816ZGTD}  08/12/2010 12:30:14  FAW0032  PC-5866
# 4   http  {D2Z8-A8NQ04XG-4780RMTE}  08/12/2010 13:35:00  BBS0039  PC-9436

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10])
df.head()
# Out:
#   source                        id                 date     user       pc
# 0  email  {Z1N2-F1FA87YB-4221ITSF}  08/12/2010 10:24:05  BBS0039  PC-9436
# 1  email  {T2G4-S9UB53ZH-3260RWIL}  08/12/2010 10:39:01  FAW0032  PC-5866
# 2  email  {C2C7-S0RT56MV-5031DXJZ}  08/12/2010 11:26:15  BBS0039  PC-9436
# 3  email  {X1C6-P0XL81JW-3816ZGTD}  08/12/2010 12:30:14  FAW0032  PC-5866
# 4   http  {D2Z8-A8NQ04XG-4780RMTE}  08/12/2010 13:35:00  BBS0039  PC-9436

# %%
#remove id
df = df.drop(['id'],axis=1)
df.head()
# Out:
#   source                 date     user       pc
# 0  email  08/12/2010 10:24:05  BBS0039  PC-9436
# 1  email  08/12/2010 10:39:01  FAW0032  PC-5866
# 2  email  08/12/2010 11:26:15  BBS0039  PC-9436
# 3  email  08/12/2010 12:30:14  FAW0032  PC-5866
# 4   http  08/12/2010 13:35:00  BBS0039  PC-9436

# %%
um.convertToDateTime(df,'date')
print(df.shape)
print(df.head())
# Out:
#   source                date     user       pc
# 0  email 2010-08-12 10:24:05  BBS0039  PC-9436
# 1  email 2010-08-12 10:39:01  FAW0032  PC-5866
# 2  email 2010-08-12 11:26:15  BBS0039  PC-9436
# 3  email 2010-08-12 12:30:14  FAW0032  PC-5866
# 4   http 2010-08-12 13:35:00  BBS0039  PC-9436
# (213, 4)
#   source                date     user       pc
# 0  email 2010-08-12 10:24:05  BBS0039  PC-9436
# 1  email 2010-08-12 10:39:01  FAW0032  PC-5866
# 2  email 2010-08-12 11:26:15  BBS0039  PC-9436
# 3  email 2010-08-12 12:30:14  FAW0032  PC-5866
# 4   http 2010-08-12 13:35:00  BBS0039  PC-9436

# %%
# um.exportFile(df,'4.2-3')

# %% [markdown]
# # Section-4 Finding Insiderthreat column

# %%
import pandas as pd
from modules import usermodules as um

# %%
file = '../dataset/r4.2/'

# %%
print('Scenario Main File Reading ... ')
df1 = pd.read_csv(file+'scenario3-transform_copy.csv')
print('Scenario Main File Reading Done !')

print('Threat File Reading ....')
df2 = pd.read_csv(file+'4.2-3_copy.csv')
print('Threat file Reading Done !')
# Out:
# Scenario Main File Reading ...
# Scenario Main File Reading Done !
# Threat File Reading ....
# Threat file Reading Done !

# %%
df1.head()
# Out:
#   insiderthreat vector                 date     user       pc activity   to  \
# 0             🤔  logon  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  NaN
# 1             🤔  logon  2010-01-02 06:50:00  LRR0148  PC-4275    Logon  NaN
# 2             🤔  logon  2010-01-02 06:53:04  LRR0148  PC-4124    Logon  NaN
# 3             🤔  logon  2010-01-02 07:00:00  MOH0273  PC-6699    Logon  NaN
# 4             🤔  logon  2010-01-02 07:00:00  IRM0931  PC-7188    Logon  NaN
#
#   from   cc  bcc  size  attachments content
# 0  NaN  NaN  NaN   NaN          NaN     NaN
# 1  NaN  NaN  NaN   NaN          NaN     NaN
# 2  NaN  NaN  NaN   NaN          NaN     NaN
# 3  NaN  NaN  NaN   NaN          NaN     NaN
# 4  NaN  NaN  NaN   NaN          NaN     NaN

# %%
#rename Source to Vector for merge purpose
df2.rename(columns={
    'source':'vector'
},inplace=True)
df2.head()
# Out:
#   vector                 date     user       pc
# 0  email  2010-08-12 10:24:05  BBS0039  PC-9436
# 1  email  2010-08-12 10:39:01  FAW0032  PC-5866
# 2  email  2010-08-12 11:26:15  BBS0039  PC-9436
# 3  email  2010-08-12 12:30:14  FAW0032  PC-5866
# 4   http  2010-08-12 13:35:00  BBS0039  PC-9436

# %%
print(df1['date'].isin(df2['date']).value_counts())
um.simpleLine()
print(df1['user'].isin(df2['user']).value_counts())
um.simpleLine()
print(df1['pc'].isin(df2['pc']).value_counts()) 
um.simpleLine()
print(df1['vector'].isin(df2['vector']).value_counts())
# Out:
# False    3890031
# True         187
# Name: date, dtype: int64
#
# ************************************
#
# False    3830703
# True       59515
# Name: user, dtype: int64
#
# ************************************
#
# False    3846541
# True       43677
# Name: pc, dtype: int64
#
# ************************************
#
# True    3890218
# Name: vector, dtype: int64

# %%
df2.head()
# Out:
#   vector                 date     user       pc
# 0  email  2010-08-12 10:24:05  BBS0039  PC-9436
# 1  email  2010-08-12 10:39:01  FAW0032  PC-5866
# 2  email  2010-08-12 11:26:15  BBS0039  PC-9436
# 3  email  2010-08-12 12:30:14  FAW0032  PC-5866
# 4   http  2010-08-12 13:35:00  BBS0039  PC-9436

# %%
df1.vector.unique()
# Out:
# array(['logon', 'email', 'device'], dtype=object)

# %%
df2.vector.unique()
# Out:
# array(['email', 'http', 'device', 'file', 'logon'], dtype=object)

# %%
df3 = pd.merge(df1,df2,how='left',indicator=True)
df3.head()
# Out:
#   insiderthreat vector                 date     user       pc activity   to  \
# 0             🤔  logon  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  NaN
# 1             🤔  logon  2010-01-02 06:50:00  LRR0148  PC-4275    Logon  NaN
# 2             🤔  logon  2010-01-02 06:53:04  LRR0148  PC-4124    Logon  NaN
# 3             🤔  logon  2010-01-02 07:00:00  MOH0273  PC-6699    Logon  NaN
# 4             🤔  logon  2010-01-02 07:00:00  IRM0931  PC-7188    Logon  NaN
#
#   from   cc  bcc  size  attachments content     _merge
# 0  NaN  NaN  NaN   NaN          NaN     NaN  left_only
# 1  NaN  NaN  NaN   NaN          NaN     NaN  left_only
# 2  NaN  NaN  NaN   NaN          NaN     NaN  left_only
# 3  NaN  NaN  NaN   NaN          NaN     NaN  left_only
# 4  NaN  NaN  NaN   NaN          NaN     NaN  left_only

# %%
#remove InsiderThreat
df4 = df3.drop(['insiderthreat'],axis=1)
df4.head()
# Out:
#   vector                 date     user       pc activity   to from   cc  bcc  \
# 0  logon  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  NaN  NaN  NaN  NaN
# 1  logon  2010-01-02 06:50:00  LRR0148  PC-4275    Logon  NaN  NaN  NaN  NaN
# 2  logon  2010-01-02 06:53:04  LRR0148  PC-4124    Logon  NaN  NaN  NaN  NaN
# 3  logon  2010-01-02 07:00:00  MOH0273  PC-6699    Logon  NaN  NaN  NaN  NaN
# 4  logon  2010-01-02 07:00:00  IRM0931  PC-7188    Logon  NaN  NaN  NaN  NaN
#
#    size  attachments content     _merge
# 0   NaN          NaN     NaN  left_only
# 1   NaN          NaN     NaN  left_only
# 2   NaN          NaN     NaN  left_only
# 3   NaN          NaN     NaN  left_only
# 4   NaN          NaN     NaN  left_only

# %%
##### rename and merge column with source
df4.rename(columns={
    '_merge':'source'
},inplace=True)
df4.head()
# Out:
#   vector                 date     user       pc activity   to from   cc  bcc  \
# 0  logon  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  NaN  NaN  NaN  NaN
# 1  logon  2010-01-02 06:50:00  LRR0148  PC-4275    Logon  NaN  NaN  NaN  NaN
# 2  logon  2010-01-02 06:53:04  LRR0148  PC-4124    Logon  NaN  NaN  NaN  NaN
# 3  logon  2010-01-02 07:00:00  MOH0273  PC-6699    Logon  NaN  NaN  NaN  NaN
# 4  logon  2010-01-02 07:00:00  IRM0931  PC-7188    Logon  NaN  NaN  NaN  NaN
#
#    size  attachments content     source
# 0   NaN          NaN     NaN  left_only
# 1   NaN          NaN     NaN  left_only
# 2   NaN          NaN     NaN  left_only
# 3   NaN          NaN     NaN  left_only
# 4   NaN          NaN     NaN  left_only

# %%
df5 =df4.copy()
display(df5.head())
display(df5.source.unique())
# Out:
#   vector                 date     user       pc activity   to from   cc  bcc  \
# 0  logon  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  NaN  NaN  NaN  NaN
# 1  logon  2010-01-02 06:50:00  LRR0148  PC-4275    Logon  NaN  NaN  NaN  NaN
# 2  logon  2010-01-02 06:53:04  LRR0148  PC-4124    Logon  NaN  NaN  NaN  NaN
# 3  logon  2010-01-02 07:00:00  MOH0273  PC-6699    Logon  NaN  NaN  NaN  NaN
# 4  logon  2010-01-02 07:00:00  IRM0931  PC-7188    Logon  NaN  NaN  NaN  NaN
#
#    size  attachments content     source
# 0   NaN          NaN     NaN  left_only
# 1   NaN          NaN     NaN  left_only
# 2   NaN          NaN     NaN  left_only
# 3   NaN          NaN     NaN  left_only
# 4   NaN          NaN     NaN  left_only
# ['left_only', 'both']
# Categories (2, object): ['left_only', 'both']

# %%
x = 'nan'
function = lambda x:0 if x == 'left_only'  else(1 if x=='both'  else x)
df5['insiderthreat'] = df5['source'].apply(function)
del df5['source']
df5.head()
# Out:
#   vector                 date     user       pc activity   to from   cc  bcc  \
# 0  logon  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  NaN  NaN  NaN  NaN
# 1  logon  2010-01-02 06:50:00  LRR0148  PC-4275    Logon  NaN  NaN  NaN  NaN
# 2  logon  2010-01-02 06:53:04  LRR0148  PC-4124    Logon  NaN  NaN  NaN  NaN
# 3  logon  2010-01-02 07:00:00  MOH0273  PC-6699    Logon  NaN  NaN  NaN  NaN
# 4  logon  2010-01-02 07:00:00  IRM0931  PC-7188    Logon  NaN  NaN  NaN  NaN
#
#    size  attachments content insiderthreat
# 0   NaN          NaN     NaN             0
# 1   NaN          NaN     NaN             0
# 2   NaN          NaN     NaN             0
# 3   NaN          NaN     NaN             0
# 4   NaN          NaN     NaN             0

# %%
df5.insiderthreat.unique()
# Out:
# [0, 1]
# Categories (2, object): [0, 1]

# %%
#Rearrange Column
arrange_column = ['insiderthreat','vector','date','user','pc','activity','to','from','cc','bcc','size','attachments','content']
df = df5.reindex(columns=arrange_column)
df.head()
# Out:
#   insiderthreat vector                 date     user       pc activity   to  \
# 0             0  logon  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  NaN
# 1             0  logon  2010-01-02 06:50:00  LRR0148  PC-4275    Logon  NaN
# 2             0  logon  2010-01-02 06:53:04  LRR0148  PC-4124    Logon  NaN
# 3             0  logon  2010-01-02 07:00:00  MOH0273  PC-6699    Logon  NaN
# 4             0  logon  2010-01-02 07:00:00  IRM0931  PC-7188    Logon  NaN
#
#   from   cc  bcc  size  attachments content
# 0  NaN  NaN  NaN   NaN          NaN     NaN
# 1  NaN  NaN  NaN   NaN          NaN     NaN
# 2  NaN  NaN  NaN   NaN          NaN     NaN
# 3  NaN  NaN  NaN   NaN          NaN     NaN
# 4  NaN  NaN  NaN   NaN          NaN     NaN

# %%
um.exportFile(df,'scenario-3-final-transform')
# Out:
# Exporting scenario-3-final-transform_copy.csv is Done !

# %%
df.dtypes
# Out:
# insiderthreat    category
# vector             object
# date               object
# user               object
# pc                 object
# activity           object
# to                 object
# from               object
# cc                 object
# bcc                object
# size              float64
# attachments       float64
# content            object
# dtype: object

# %% [markdown]
# ''' #vector http = 0 email = 1 device = 2 logon = 3 '''

# %%
x = df['vector']
function = lambda x:3 if x == 'logon'  else(2 if x=='device'  else 1)
df['vector'] = df['vector'].apply(function)
df.head()
# Out:
#   insiderthreat  vector                 date     user       pc activity   to  \
# 0             0       3  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  NaN
# 1             0       3  2010-01-02 06:50:00  LRR0148  PC-4275    Logon  NaN
# 2             0       3  2010-01-02 06:53:04  LRR0148  PC-4124    Logon  NaN
# 3             0       3  2010-01-02 07:00:00  MOH0273  PC-6699    Logon  NaN
# 4             0       3  2010-01-02 07:00:00  IRM0931  PC-7188    Logon  NaN
#
#   from   cc  bcc  size  attachments content
# 0  NaN  NaN  NaN   NaN          NaN     NaN
# 1  NaN  NaN  NaN   NaN          NaN     NaN
# 2  NaN  NaN  NaN   NaN          NaN     NaN
# 3  NaN  NaN  NaN   NaN          NaN     NaN
# 4  NaN  NaN  NaN   NaN          NaN     NaN

# %%
#convertion level
df['date'] = pd.to_datetime(df['date'])
df['user'] = df['user'].astype('category')
df['pc'] = df['pc'].astype('category')
df['activity'] = df['activity'].astype('category')
um.dividerLine('Data Type after Convertion')
print(df.dtypes)
# Out:
# ************************************
#
# Data Type after Convertion
#
# ************************************
#
# insiderthreat          category
# vector                    int64
# date             datetime64[ns]
# user                   category
# pc                     category
# activity               category
# to                       object
# from                     object
# cc                       object
# bcc                      object
# size                    float64
# attachments             float64
# content                  object
# dtype: object

# %%
um.exportFile(df,'scenario3-training-dataset-transformed-tf')
# Out:
# Exporting scenario3-training-dataset-transformed-tf_copy.csv is Done !

# %%
df.shape
# Out:
# (3890218, 13)

# %%
len(df.loc[df['insiderthreat']==1])
# Out:
# 150

# %%
df.iloc[1324134:1324138,:]
# Out:
#         insiderthreat  vector                date     user       pc activity  \
# 1324134             1       1 2010-06-10 07:54:10  CSC0217  PC-6377    email
# 1324135             0       1 2010-06-10 07:54:29  AJD0074  PC-3135    email
# 1324136             0       1 2010-06-10 07:54:34  AJD0074  PC-3135    email
# 1324137             0       1 2010-06-10 07:54:35  MBJ0312  PC-5250    email
#
#                                                         to  \
# 1324134                     Frances.Alisa.Wiggins@dtaa.com
# 1324135                              Moss-Declan@gmail.com
# 1324136                        Declan.Lester.Moss@dtaa.com
# 1324137  Allegra.Bree.Coffey@dtaa.com;Josiah.Chester.Gr...
#
#                                      from   cc                       bcc  \
# 1324134  Cathleen.Samantha.Craig@dtaa.com  NaN                       NaN
# 1324135                 Alden_Day@cox.net  NaN         Alden_Day@cox.net
# ...

# %%
chunk_size =5000
for  chunks  in pd.read_csv('../dataset/r4.2/scenario3-training-dataset-transformed-tf_copy.csv' chunks=chunk_size):
    print(chunks)
# Out:
#   File "<ipython-input-31-dea2b938dacc>", line 2
#     for  chunks  in pd.read_csv('../dataset/r4.2/scenario3-training-dataset-transformed-tf_copy.csv' chunks=chunk_size):
#                                                                                                      ^
# SyntaxError: invalid syntax
