# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# path = "/content/gdrive/MyDrive/dataset/"
path="../dataset new/"

# %%
df_email_init = pd.read_csv(path+'email.csv')
df_email, df_email_test = train_test_split(df_email_init,test_size=0.2, random_state=42)
df_email_test.to_csv('../testing/email_test.csv')
display(df_email.shape)
display(df_email.head())
# Out:
# (1580080, 7)
#                                id                 date  \
# 1730043  {B7K5-M2PZ77HC-5876WFKM}  03/11/2011 13:54:54
# 891099   {O4L4-Z1TM67BK-9791ABJH}  08/07/2010 15:39:16
# 904286   {H5K0-P9LF20QW-0224AKPE}  08/11/2010 09:34:00
# 411124   {A6L8-K1LB07BZ-1714GBQW}  04/12/2010 08:28:49
# 738640   {J0W4-I2MD10PP-4478HIVL}  06/30/2010 11:41:28
#
#                                                         to  \
# 1730043  Adena.Guinevere.Diaz@dtaa.com;Karleigh.Lareina...
# 891099                         Maggie.Tara.Jarvis@dtaa.com
# 904286   Xavier.Ryan.Rosa@hp.com;Lysandra.Kendall.Price...
# 411124                       Alika.Odessa.Hammond@dtaa.com
# 738640   Jessamine.Jeanette.Pitts@dtaa.com;Sawyer.Josia...
#
#                                   from   size  attachments  \
# 1730043  Cameron.Meghan.Sloan@dtaa.com  48940            0
# 891099   William.Xerxes.Wiley@dtaa.com  39751            0
# 904286   Tyrone.Hamilton.Park@dtaa.com  14821            0
# 411124      Boris.Samuel.Paul@dtaa.com  36054            1
# 738640     Alana.Martina.Nash@dtaa.com  17914            4
#
#                                                    content
# 1730043  dean 423 columns3 meandered blackburn ruabon b...
# 891099   rimet ulises patenaude bolivian varallo jawad ...
# 904286   thinsplike hst euv 446250 00028 26312 dimensio...
# 411124   curthose primi thurgot henrici maternus thurgo...
# 738640   spurrier craftiest clemson stallions acc capua...

# %%
df_user_email_init = pd.read_csv(path+'user_email.csv')
df_user_email, df_user_email_test = train_test_split(df_user_email_init,test_size=0.2, random_state=42)
df_user_email_test.to_csv('../testing/user_email_test.csv')
del df_user_email['Unnamed: 0']

display(df_user_email.shape)
display(df_user_email)
# Out:
# (13868, 3)
#                employee_name  user_id                           email
# 6909    Jocelyn Nyssa Wooten  JNW0252   Jocelyn.Nyssa.Wooten@dtaa.com
# 3995       Melyssa Yuri Owen  MYO0768      Melyssa.Yuri.Owen@dtaa.com
# 15088  Victoria Regan Fisher  VRF0401  Victoria.Regan.Fisher@dtaa.com
# 11432  Rachel Kelsie Puckett  RKP0922  Rachel.Kelsie.Puckett@dtaa.com
# 12299   Macaulay Kevin Rocha  MKR0025   Macaulay.Kevin.Rocha@dtaa.com
# ...                      ...      ...                             ...
# 11284  Nicolas Arsenio Burke  NAB0467  Nicolas.Arsenio.Burke@dtaa.com
# 11964     Pamela Sade Newton  PSN0949     Pamela.Sade.Newton@dtaa.com
# 5390        Alice Inez Riley  AIR0197       Alice.Inez.Riley@dtaa.com
# 860      Quentin Elvis Brown  QEB0780    Quentin.Elvis.Brown@dtaa.com
# 15795     Stella Teagan Moon  STM0826     Stella.Teagan.Moon@dtaa.com
#
# [13868 rows x 3 columns]

# %%
df_email['from'].unique()
# Out:
# array(['Cameron.Meghan.Sloan@dtaa.com', 'William.Xerxes.Wiley@dtaa.com',
#        'Tyrone.Hamilton.Park@dtaa.com', 'Boris.Samuel.Paul@dtaa.com',
#        'Alana.Martina.Nash@dtaa.com', 'Ezra.Valentine.Marsh@dtaa.com',
#        'Linda.Hedwig.Shepard@dtaa.com', 'Imelda.Zelda.Rodriquez@dtaa.com',
#        'Mufutau.Brandon.Whitehead@dtaa.com',
#        'Alexis.Whilemina.Hammond@dtaa.com',
#        'Elizabeth.Yael.Odonnell@dtaa.com',
#        'Aurelia.Shannon.Sparks@dtaa.com',
#        'Hayden.Gregory.Simpson@dtaa.com',
#        'Angelica.Stephanie.Holloway@dtaa.com',
#        'Lionel.Henry.Morgan@dtaa.com', 'Francis.Axel.Mcintyre@dtaa.com',
#        'Marcia.Vielka.Howard@dtaa.com', 'Emi.Sydnee.Mendoza@dtaa.com',
#        'Amy.Kerry.Willis@dtaa.com', 'Farrah.Neve.Fuller@dtaa.com',
#        'Odessa.Tatiana.Ryan@dtaa.com', 'Austin.Hyatt.Battle@dtaa.com',
#        'Wing.Jeremy.Peters@dtaa.com', 'Daphne.Samantha.Lyons@dtaa.com',
#        'Karina.Taylor.Potts@dtaa.com', 'Robert.Abdul.Weaver@dtaa.com',
#        'Mariko.Pascale.Rivas@dtaa.com', 'Brett.Nathan.Schneider@dtaa.com',
#        'Jolie.Alea.Walker@dtaa.com', 'Casey.Nicolas.Cochran@dtaa.com',
#        'Amir.Ignatius.Randolph@dtaa.com',
#        'Melodie.Delilah.Wilson@dtaa.com',
#        'Jerome.Hunter.Calhoun@dtaa.com',
#        'Pearl.Nomlanga.Bernard@dtaa.com', 'Dante.Yoshio.Bates@dtaa.com',
#        'Tatum.Sacha.Elliott@dtaa.com', 'Holly.Gemma.Scott@dtaa.com',
#        'Quinn.Dylan.Valenzuela@dtaa.com',
#        'Hammett.Jonah.Saunders@dtaa.com',
#        'Bo.Gretchen.Zimmerman@dtaa.com',
#        'Nomlanga.Idola.Mcdowell@dtaa.com', 'Oliver.Martin.Byers@dtaa.com',
#        'Xena.Sage.Anthony@dtaa.com', 'Prescott.Charles.Arnold@dtaa.com',
#        'Kendall.Raven.Conner@dtaa.com', 'Elaine.Meghan.Garrett@dtaa.com',
#        'Fallon.Nola.Simpson@dtaa.com', 'Kimberley.Stella.Dawson@dtaa.com',
#        'Heather.Naida.Espinoza@dtaa.com', 'Len.Mohammad.Le@dtaa.com',
#        'Blythe.Yoshi.Briggs@dtaa.com', 'Gage.Omar.Graham@dtaa.com',
#        'Camilla.Callie.Wolf@dtaa.com', 'Gage.Kenneth.Johnson@dtaa.com',
#        'Conan.Phillip.Gamble@dtaa.com', 'Asher.Lucas.Daniel@dtaa.com',
#        'Harper.Rogan.Lambert@dtaa.com', 'Kuame.Grady.Collins@dtaa.com',
#        'Charde.Ramona.Lara@dtaa.com', 'Wendy.Aline.Mccullough@dtaa.com',
#        'Grady.Erasmus.Dunlap@dtaa.com', 'Ira.Ulric.Matthews@dtaa.com',
#        'Abraham.Lucas.Sosa@dtaa.com', 'Wendy.Lila.Thompson@dtaa.com',
#        'Barclay.Raymond.Mcclain@dtaa.com', 'Wade.Cain.Leach@dtaa.com',
#        'Price.Brent.Zamora@dtaa.com', 'Quin.Roanna.Riddle@dtaa.com',
#        'Willa.Signe.Mayo@dtaa.com', 'Quon.Pascale.Melton@dtaa.com',
#        'Orla.Velma.Cervantes@dtaa.com', 'Amery.Dolan.Ross@dtaa.com',
#        'Nadine.Xerxes.Gould@dtaa.com', 'Louis.Ronan.Carter@dtaa.com',
#        'Ralph.Kadeem.Hull@dtaa.com', 'Tatum.Desiree.Wall@dtaa.com',
#        'Jamalia.Brynne.Sherman@dtaa.com', 'Lamar.Oscar.Warner@dtaa.com',
#        'Zelda.Naomi.Frost@dtaa.com', 'Bruno.Yasir.Nieves@dtaa.com',
#        'Yasir.Reece.Fowler@dtaa.com', 'Herrod.Gabriel.Howard@dtaa.com',
#        'Darryl.Chelsea.Taylor@dtaa.com',
#        'Merrill.Lucian.Hammond@dtaa.com',
#        'Judah.Maxwell.Armstrong@dtaa.com', 'Timothy.James.Bird@dtaa.com',
#        'Jessamine.Iona.Fletcher@dtaa.com',
#        'Melissa.Aurelia.Fitzgerald@dtaa.com',
#        'Nichole.Destiny.Hendrix@dtaa.com', 'Ruby.Quynn.Knowles@dtaa.com',
#        'Brandon.Vladimir.Vaughan@dtaa.com',
#        'Lareina.Jessica.Avila@dtaa.com',
#        'Mechelle.Teegan.Maynard@dtaa.com',
#        'Yoshio.Hedley.Calhoun@dtaa.com', 'Stephen.Patrick.Bray@dtaa.com',
#        'Sara.Indigo.Berger@dtaa.com', 'Medge.Sarah.Boyer@dtaa.com',
#        'Charissa.Nadine.Kramer@dtaa.com', 'Jin.Price.Sims@dtaa.com',
#        'Avye.Lucy.Weber@dtaa.com', 'Desirae.Reagan.Lindsey@dtaa.com',
#        'Alice.Inez.Riley@dtaa.com', 'Quentin.Elvis.Brown@dtaa.com',
#        'Quintessa.Adara.Mcneil@dtaa.com', 'Dean.Denton.Leblanc@dtaa.com',
#        'Jerry.Kuame.Morgan@dtaa.com', 'Dahlia.Audrey.Hodge@dtaa.com',
#        'Rachel.Martha.Arnold@dtaa.com', 'Tanek.Daquan.Carroll@dtaa.com',
#        'Amena.Anika.Rocha@dtaa.com', 'Keelie.Kyla.Castro@dtaa.com',
#        'Quyn.Xaviera.Lewis@dtaa.com', 'Driscoll.Yoshio.Strong@dtaa.com',
#        'Selma.Sacha.House@dtaa.com', 'Taylor.Omar.Chavez@dtaa.com',
#        'William.Boris.Carver@dtaa.com', 'Eric.Ferdinand.White@dtaa.com',
#        'Beverly.Piper.Burnett@dtaa.com',
#        'William.Kadeem.Rowland@dtaa.com', 'Hollee.Noelle.Walls@dtaa.com',
#        'Edward.Clayton.Sutton@dtaa.com', 'Alexandra.Jane.Allen@dtaa.com',
#        'Lani.Linda.Madden@dtaa.com', 'Gavin.Gannon.Mcgowan@dtaa.com',
#        'Davis.Joseph.Hurley@dtaa.com', 'Joel.Octavius.Howell@dtaa.com',
#        'Germane.Gloria.Murray@dtaa.com',
#        'Jermaine.Theodore.Burke@dtaa.com',
#        'Olympia.Genevieve.Grant@dtaa.com', 'Ainsley.Althea.Best@dtaa.com',
#        'Alexander.Malcolm.Turner@dtaa.com',
#        'Allistair.Akeem.Nichols@dtaa.com',
#        'Serina.Brenda.Mccray@dtaa.com', 'Carol.Shafira.Daniel@dtaa.com',
#        'Garrett.Randall.Montoya@dtaa.com',
#        'Robert.Elvis.Morrison@dtaa.com',
#        'Stephanie.Jade.Kennedy@dtaa.com',
#        'Chanda.Jena.Valentine@dtaa.com',
#        'Melodie.Rachel.Schneider@dtaa.com',
#        'Joseph.Xenos.Hutchinson@dtaa.com',
#        'Shafira.Helen.Reynolds@dtaa.com',
#        'Oliver.Fitzgerald.Stevenson@dtaa.com',
#        'Florence.Regan.Lloyd@dtaa.com', 'Judah.Palmer.Mcmahon@dtaa.com',
#        'Vance.Nicholas.Lee@dtaa.com', 'Basil.Rashad.Burgess@dtaa.com',
#        'Amaya.Miranda.Tate@dtaa.com', 'Kendall.Indigo.Hatfield@dtaa.com',
#        'Keegan.Hayden.Edwards@dtaa.com',
#        'Odysseus.Chaney.Chambers@dtaa.com',
#        'Stuart.Lane.Brennan@dtaa.com', 'Arden.Leo.Chase@dtaa.com',
#        'Kylynn.Shelby.Greene@dtaa.com',
#        'Jermaine.Jasper.Lawrence@dtaa.com',
#        'James.Aladdin.Bradshaw@dtaa.com', 'Joseph.Hamish.House@dtaa.com',
#        'Moses.Fletcher.Blackburn@dtaa.com',
#        'Carla.Claire.Blackwell@dtaa.com', 'Gage.Sylvester.Olson@dtaa.com',
#        'Garrett.Akeem.Potts@dtaa.com', 'Joan.Lael.Ingram@dtaa.com',
#        'Scott.Damian.Shaw@dtaa.com', 'Melyssa.Yuri.Owen@dtaa.com',
#        'Galena.Margaret.Mcconnell@dtaa.com', 'Beau.Raja.Fulton@dtaa.com',
#        'Shoshana.Lana.Ingram@dtaa.com', 'Dennis.Jelani.Mcclure@dtaa.com',
#        'Nichole.Felicia.Adams@dtaa.com', 'Alvin.David.Contreras@dtaa.com',
#        'Leonard.Wesley.Barber@dtaa.com',
#        'Plato.Chandler.Valentine@dtaa.com',
#        'Lucius.Kamal.Goodman@dtaa.com', 'Hammett.Cain.Richards@dtaa.com',
#        'Lareina.Sierra.Cantu@dtaa.com', 'Mannix.Brent.Bradley@dtaa.com',
#        'Destiny.Katelyn.Ochoa@dtaa.com', 'Kendall.Brenna.Franco@dtaa.com',
#        'Ivor.Talon.Parker@dtaa.com', 'Evangeline.Sage.Houston@dtaa.com',
#        'Libby.Jaden.Dickson@dtaa.com', 'William.Kelly.Sosa@dtaa.com',
#        'Whilemina.Quinn.Wall@dtaa.com', 'Audra.Hilda.Mclaughlin@dtaa.com',
#        'James.Chester.English@dtaa.com', 'Darius.Ethan.Carter@dtaa.com',
#        'Ray.Xanthus.Alvarez@dtaa.com', 'Neville.Jamal.Hester@dtaa.com',
#        'Carlos.Nathaniel.Waller@dtaa.com', 'Aurora.Kelly.Mendez@dtaa.com',
#        'Zephania.Carson.Le@dtaa.com', 'Melinda.Hanna.French@dtaa.com',
#        'Miranda.Raven.Shepherd@dtaa.com', 'Edan.Ray.Christian@dtaa.com',
#        'Bree.Daria.Alexander@dtaa.com',
#        'Ferdinand.Jonathan.Dyer@dtaa.com', 'Ella.Gloria.Rocha@dtaa.com',
#        'Ainsley.Chelsea.Weiss@dtaa.com', 'Calista.Brenna.Page@dtaa.com',
#        'Paul.Troy.Small@dtaa.com', 'Savannah.Alana.Morton@dtaa.com',
#        'Hadley.McKenzie.Pearson@dtaa.com', 'Bruce.Camden.Mann@dtaa.com',
#        'Farrah.Chantale.Wagner@dtaa.com', 'Kirk.Wing.Heath@dtaa.com',
#        'Laurel.Mallory.House@dtaa.com', 'Quinn.Kaden.Rojas@dtaa.com',
#        'Francesca.Alea.Avery@dtaa.com', 'Robert.Tyrone.Sutton@dtaa.com',
#        'Irma.Nina.Savage@dtaa.com', 'Stephanie.Kim.Greene@dtaa.com',
#        'Carson.Emmanuel.Schultz@dtaa.com',
#        'Neville.Leonard.Pacheco@dtaa.com',
#        'Colorado.Blaze.Dejesus@dtaa.com', 'Nerea.Ingrid.Good@dtaa.com',
#        'Jael.Phyllis.Contreras@dtaa.com',
#        'Brittany.Imani.Duncan@dtaa.com', 'Hiroko.Dora.Keith@dtaa.com',
#        'Macaulay.Cadman.Leonard@dtaa.com',
#        'Camden.Daniel.Whitley@dtaa.com',
#        'Madeline.Beverly.Dudley@dtaa.com', 'Aimee.Bo.Murphy@dtaa.com',
#        'Benjamin.Elton.Ray@dtaa.com', 'Alexa.Allegra.Walton@dtaa.com',
#        'India.Alice.Wyatt@dtaa.com', 'Thaddeus.Brock.Mercado@dtaa.com',
#        'Aquila.Jasper.Quinn@dtaa.com', 'Sierra.Kimberly.Pope@dtaa.com',
#        'Sonia.Mary.Vincent@dtaa.com', 'Jermaine.Dominic.Dorsey@dtaa.com',
#        'Marsden.William.Langley@dtaa.com', 'Vielka.Kaye.Berry@dtaa.com',
#        'Connor.Boris.Austin@dtaa.com', 'Emi.Vanna.Hampton@dtaa.com',
#        'Sheila.Mollie.Mccormick@dtaa.com', 'Aaron.Micah.Wilkins@dtaa.com',
#        'Orson.Dylan.Gordon@dtaa.com', 'Nicholas.Theodore.Horton@dtaa.com',
#        'Xavier.Lucas.Black@dtaa.com', 'Aline.Beverly.Woodward@dtaa.com',
#        'Jane.Kylee.Bolton@dtaa.com', 'Fredericka.Martina.Lynn@dtaa.com',
#        'Jael.Cara.Shepard@dtaa.com', 'Nasim.Luke.Bowen@dtaa.com',
#        'Sebastian.Lucian.Witt@dtaa.com', 'Lewis.Len.Sweeney@dtaa.com',
#        'Galvin.Robert.Williams@dtaa.com',
#        'Stephanie.Kylie.Alexander@dtaa.com',
#        'Preston.Julian.Calhoun@dtaa.com', 'Brody.Dieter.Salazar@dtaa.com',
#        'Belle.Catherine.Hodges@dtaa.com', 'May.Dominique.Norris@dtaa.com',
#        'Ishmael.Slade.Parrish@dtaa.com',
#        'Ulysses.Marvin.Alvarado@dtaa.com',
#        'Brady.Jameson.Trevino@dtaa.com', 'Elvis.Mannix.Murphy@dtaa.com',
#        'Lev.Wade.Lopez@dtaa.com', 'Karleigh.Lareina.Rojas@dtaa.com',
#        'Jameson.Asher.Blake@dtaa.com', 'Hilary.Ocean.Allen@dtaa.com',
#        'Katell.Fiona.Swanson@dtaa.com', 'Lucius.Joshua.Waters@dtaa.com',
#        'Rosalyn.Jayme.Cabrera@dtaa.com', 'Ulric.Benjamin.Morse@dtaa.com',
#        'Steven.Ethan.Mayer@dtaa.com', 'Zoe.Xena.Alvarado@dtaa.com',
#        'Sonya.Charity.Reed@dtaa.com', 'Paula.Julie.Tate@dtaa.com',
#        'Ariana.Orla.Padilla@dtaa.com', 'Oleg.Dalton.Hughes@dtaa.com',
#        'Samuel.Elton.Bennett@dtaa.com', 'Cynthia.Cameron.Day@dtaa.com',
#        'Donovan.Robert.Houston@dtaa.com', 'Shana.Regan.Sanders@dtaa.com',
#        'Yen.Sage.Baxter@dtaa.com', 'Kelsey.Demetria.Goff@dtaa.com',
#        'John.Kato.Gibson@dtaa.com', 'Aurora.Fatima.Marquez@dtaa.com',
#        'Jena.Libby.Atkinson@dtaa.com', 'Nyssa.Urielle.Davenport@dtaa.com',
#        'Darryl.Ciara.Zamora@dtaa.com', 'Ira.Eaton.Frank@dtaa.com',
#        'Jocelyn.Amanda.Carney@dtaa.com', 'Gillian.Bo.Malone@dtaa.com',
#        'Mona.Ina.Cox@dtaa.com', 'Stuart.Otto.Shepherd@dtaa.com',
#        'Calista.Rylee.Gilbert@dtaa.com', 'Hope.Keelie.Knight@dtaa.com',
#        'Kuame.Keane.Bradley@dtaa.com', 'Kaye.Aurelia.Hull@dtaa.com',
#        'Callie.Chastity.Wiggins@dtaa.com', 'Pamela.Sade.Newton@dtaa.com',
#        'Wylie.Akeem.Frederick@dtaa.com', 'Meghan.Janna.Holder@dtaa.com',
#        'Dominic.Alvin.Moody@dtaa.com', 'Yoko.Josephine.Travis@dtaa.com',
#        'Tate.Jonathan.Walls@dtaa.com', 'Kimberley.Taylor.Lowery@dtaa.com',
#        'Leonard.Thaddeus.Bryan@dtaa.com', 'Amos.Carson.Emerson@dtaa.com',
#        'Brady.Ahmed.Bailey@dtaa.com', 'Montana.Rebecca.Hendrix@dtaa.com',
#        'Medge.Sloane.Burns@dtaa.com', 'Fuller.Upton.Mcclure@dtaa.com',
#        'Maxwell.William.Coffey@dtaa.com',
#        'Randall.Deacon.Vaughan@dtaa.com',
#        'Kirestin.Michelle.Hull@dtaa.com', 'Todd.Blaine.Francis@dtaa.com',
#        'Emerald.Ariana.Bryan@dtaa.com', 'Raven.Lacota.Dixon@dtaa.com',
#        'Judah.Coby.Martin@dtaa.com', 'Allegra.Rosalyn.Serrano@dtaa.com',
#        'William.Preston.Figueroa@dtaa.com',
#        'Malik.Brandon.Weeks@dtaa.com', 'Keane.Merrill.Kinney@dtaa.com',
#        'Brendan.William.Kirby@dtaa.com', 'Chloe.Shaine.Weiss@dtaa.com',
#        'Nichole.Guinevere.Fields@dtaa.com',
#        'Blair.Mannix.Acevedo@dtaa.com', 'Vaughan.Leroy.Barton@dtaa.com',
#        'Blake.Martin.Barton@dtaa.com', 'Abel.Emmanuel.Wright@dtaa.com',
#        'Alana.Irma.Guzman@dtaa.com', 'Kelly.Hector.Mendoza@dtaa.com',
#        'Nichole.Anika.Horton@dtaa.com', 'Judah.Blake.Sykes@dtaa.com',
#        'Blythe.Bertha.Barker@dtaa.com', 'Louis.Seth.Golden@dtaa.com',
#        'Alexander.Dieter.Goff@dtaa.com',
#        'Prescott.Steven.Pruitt@dtaa.com', 'Renee.Amanda.Casey@dtaa.com',
#        'Damon.Jesse.Gallegos@dtaa.com', 'Ignacia.Phoebe.Collier@dtaa.com',
#        'Ila.Frances.Stephenson@dtaa.com', 'Macon.Tyler.Little@dtaa.com',
#        'Ann.Rose.Curry@dtaa.com', 'Ronan.Richard.Glenn@dtaa.com',
#        'Fredericka.Xena.Alston@dtaa.com', 'Albert.Kevin.Terry@dtaa.com',
#        'Casey.Tate.Wood@dtaa.com', 'Dieter.Hashim.Cole@dtaa.com',
#        'Carlos.Francis.Duran@dtaa.com', 'Tamekah.Cara.Woodard@dtaa.com',
#        'Karina.Madonna.Jennings@dtaa.com', 'Ebony.Iola.Tate@dtaa.com',
#        'Jonah.Connor.Henson@dtaa.com', 'Xerxes.Baker.Hansen@dtaa.com',
#        'Adam.Clark.Lindsey@dtaa.com', 'Leo.William.Roberson@dtaa.com',
#        'Mohammad.Keane.Terrell@dtaa.com', 'Malik.Zahir.Mcknight@dtaa.com',
#        'Brock.Zeus.Kim@dtaa.com', 'Vielka.Lillith.Henson@dtaa.com',
#        'Ulla.Ila.Lane@dtaa.com', 'Stella.Teagan.Moon@dtaa.com',
#        'Tatiana.Ruby.Sanchez@dtaa.com', 'Aidan.Otto.Aguirre@dtaa.com',
#        'Peter.Uriah.Horn@dtaa.com', 'Xavier.Gannon.Eaton@dtaa.com',
#        'Nicole.Vivian.Mccall@dtaa.com',
#        'Celeste.Charissa.Guthrie@dtaa.com', 'Levi.Uriah.West@dtaa.com',
#        'Bevis.Jelani.Cobb@dtaa.com', 'Albert.Wayne.Barton@dtaa.com',
#        'Paloma.Caryn.Gilmore@dtaa.com', 'Akeem.Bradley.Mercer@dtaa.com',
#        'Conan.Abbot.Gonzalez@dtaa.com',
#        'Graiden.Andrew.Whitfield@dtaa.com',
#        'Macaulay.Akeem.Barnett@dtaa.com',
#        'Jarrod.Kermit.Roberts@dtaa.com', 'Ezra.Hop.Knapp@dtaa.com',
#        'Declan.Henry.Brennan@dtaa.com', 'Bernard.Oscar.Kemp@dtaa.com',
#        'Erin.Erica.Ward@dtaa.com', 'Nichole.Vielka.Sandoval@dtaa.com',
#        'Quail.Kerry.Ayers@dtaa.com', 'Damon.Isaac.Macias@dtaa.com',
#        'Hilel.Lester.Schmidt@dtaa.com', 'Travis.Dean.Jimenez@dtaa.com',
#        'Tad.Charles.Knight@dtaa.com', 'Ima.Melanie.Wolfe@dtaa.com',
#        'Ulric.Jack.Walls@dtaa.com', 'Brittany.Tashya.Walsh@dtaa.com',
#        'Alan.Gavin.Gray@dtaa.com', 'Scarlett.Delilah.Becker@dtaa.com',
#        'Thor.Talon.Pacheco@dtaa.com', 'Aurelia.Risa.Waters@dtaa.com',
#        'Clark.Kibo.Russo@dtaa.com', 'Buffy.Unity.Guzman@dtaa.com',
#        'MacKensie.Courtney.Boone@dtaa.com', 'Fiona.Adena.Bowen@dtaa.com',
#        'Quinn.Quentin.Boyer@dtaa.com', 'Tashya.Dawn.Bowers@dtaa.com',
#        'Erasmus.Knox.Campos@dtaa.com', 'Ahmed.Walker.Mays@dtaa.com',
#        'Walter.Sloane.Garcia@dtaa.com', 'Paloma.Bo.Buchanan@dtaa.com',
#        'Branden.Kirk.Acevedo@dtaa.com', 'Buffy.Yvette.Nielsen@dtaa.com',
#        'Edward.Elijah.Robbins@dtaa.com', 'Keelie.Carol.Sawyer@dtaa.com',
#        'Renee.Kiayada.Jarvis@dtaa.com', 'John.Ryder.Gibson@dtaa.com',
#        'Rachel.Olga.Serrano@dtaa.com', 'Aidan.Blake.Callahan@dtaa.com',
#        'Stephen.Nasim.Haley@dtaa.com', 'Jayme.Kylie.Petty@dtaa.com',
#        'Quynn.Lois.Crane@dtaa.com', 'Jameson.Beck.Anthony@dtaa.com',
#        'Chelsea.Urielle.Mckinney@dtaa.com', 'Buffy.Briar.Scott@dtaa.com',
#        'Wanda.TaShya.Winters@dtaa.com', 'Macy.Geraldine.Mosley@dtaa.com',
#        'Courtney.Jena.Garza@dtaa.com', 'Jena.Bianca.Rosario@dtaa.com',
#        'Nicholas.Anthony.Hyde@dtaa.com', 'Maggie.Tara.Jarvis@dtaa.com',
#        'Rudyard.Carlos.Hahn@dtaa.com', 'Bradley.Kevin.Austin@dtaa.com',
#        'Aretha.May.Willis@dtaa.com', 'Ronan.Colt.Wolf@dtaa.com',
#        'Nina.Evangeline.Horne@dtaa.com', 'Whoopi.Evelyn.Moore@dtaa.com',
#        'Brynne.Illiana.Dickerson@dtaa.com',
#        'Maisie.Cassidy.Wooten@dtaa.com', 'Cruz.Jasper.Douglas@dtaa.com',
#        'Brielle.Lydia.Boone@dtaa.com',
#        'Adrienne.Miranda.Rodriquez@dtaa.com', 'Sade.Nola.Mejia@dtaa.com',
#        'Kennedy.Cooper.Wheeler@dtaa.com', 'Meghan.Bo.Duncan@dtaa.com',
#        'Calista.Gisela.Hudson@dtaa.com', 'Stacey.Nicole.Duran@dtaa.com',
#        'Isadora.Carla.Robinson@dtaa.com',
#        'Madeson.Ciara.Cleveland@dtaa.com', 'Inga.Ruth.Short@dtaa.com',
#        'James.Orson.Pace@dtaa.com', 'Zeph.Bruce.Love@dtaa.com',
#        'Garrett.Kibo.Tanner@dtaa.com', 'Emmanuel.Jonathan.Olson@dtaa.com',
#        'Lavinia.Alisa.Cross@dtaa.com', 'Regan.Ebony.Fitzpatrick@dtaa.com',
#        'Joshua.Aquila.Frost@dtaa.com', 'Keely.Abra.Pate@dtaa.com',
#        'Aubrey.Gillian.Hendricks@dtaa.com',
#        'Hiroko.Keely.Cochran@dtaa.com', 'Sebastian.Nash.Murray@dtaa.com',
#        'Jolie.Stacy.Butler@dtaa.com', 'Beverly.Kim.Hendricks@dtaa.com',
#        'Ariel.Carly.Horton@dtaa.com', 'Eaton.Tyrone.Sellers@dtaa.com',
#        'Noble.Fulton.Navarro@dtaa.com', 'Lillian.Velma.Landry@dtaa.com',
#        'Tanya.Cameron.Gray@dtaa.com', 'Cleo.Barbara.Byers@dtaa.com',
#        'Lester.William.Welch@dtaa.com', 'Aidan.Gregory.Rush@dtaa.com',
#        'Michelle.Ocean.Riggs@dtaa.com', 'Quon.Mallory.Vinson@dtaa.com',
#        'Gregory.Steven.Patton@dtaa.com', 'Iliana.Reagan.Wyatt@dtaa.com',
#        'Richard.Cade.Dunn@dtaa.com', 'Hamilton.Jonah.Bridges@dtaa.com',
#        'Fuller.Hu.Blankenship@dtaa.com',
#        'Jasper.Yardley.Mercado@dtaa.com',
#        'Dexter.Brandon.Hickman@dtaa.com',
#        'Michael.Aladdin.Nelson@dtaa.com', 'Baxter.Simon.Rosales@dtaa.com',
#        'Ivana.Amela.Flowers@dtaa.com', 'Dante.Kirk.King@dtaa.com',
#        'Dorian.Dominic.Burt@dtaa.com', 'Dalton.Lance.Sexton@dtaa.com',
#        'Desiree.Noelani.Smith@dtaa.com', 'Linus.Vincent.Stout@dtaa.com',
#        'Marcia.Britanney.Holland@dtaa.com',
#        'Unity.Judith.Vaughan@dtaa.com', 'Phoebe.Tatum.Hines@dtaa.com',
#        'Hilel.Wade.Rocha@dtaa.com', 'Stella.Sarah.Petty@dtaa.com',
#        'Hilary.Erin.Faulkner@dtaa.com', 'Iona.Constance.Barr@dtaa.com',
#        'Raymond.Hector.Woodward@dtaa.com', 'Yoshi.Freya.Roberts@dtaa.com',
#        'Lareina.Quintessa.Decker@dtaa.com',
#        'Chantale.Odette.Massey@dtaa.com', 'Aubrey.Joel.Stone@dtaa.com',
#        'Stewart.Chester.Collier@dtaa.com',
#        'Camilla.Brynne.Boyle@dtaa.com',
#        'Elizabeth.Josephine.Gay@dtaa.com', 'Riley.Inez.Stein@dtaa.com',
#        'Gage.Grady.Kane@dtaa.com', 'Aiko.Raven.Howell@dtaa.com',
#        'Henry.Harrison.Rosario@dtaa.com', 'Xena.Rylee.Emerson@dtaa.com',
#        'Adam.Judah.Guerra@dtaa.com', 'Mikayla.Chloe.Burke@dtaa.com',
#        'Giselle.Xerxes.Bowers@dtaa.com',
#        'Stephanie.Vivian.Moody@dtaa.com', 'Amery.Blaine.Melton@dtaa.com',
#        'Acton.Wayne.Wolfe@dtaa.com', 'Pascale.Quail.Christensen@dtaa.com',
#        'Hope.Madaline.Livingston@dtaa.com',
#        'Brittany.Shelby.Hawkins@dtaa.com',
#        'Amethyst.Jillian.Reed@dtaa.com',
#        'Xander.Garrison.Wilkinson@dtaa.com',
#        'Quamar.Kennan.Greer@dtaa.com',
#        'Ferdinand.Chester.Ramirez@dtaa.com',
#        'Trevor.James.Henson@dtaa.com', 'Barry.Igor.Trevino@dtaa.com',
#        'Coby.Daniel.Alvarado@dtaa.com', 'Reed.Barclay.Moody@dtaa.com',
#        'Dominique.Dara.Emerson@dtaa.com',
#        'Jonathan.Callum.Leblanc@dtaa.com', 'Devin.Tobias.Adams@dtaa.com',
#        'Geoffrey.Reed.Riddle@dtaa.com', 'Lars.Jared.Barnes@dtaa.com',
#        'Carissa.Quinn.Solis@dtaa.com', 'Margaret.Piper.Mercado@dtaa.com',
#        'Jeanette.Zelenia.Todd@dtaa.com', 'Wynne.Darryl.Chen@dtaa.com',
#        'Keefe.Benjamin.Justice@dtaa.com', 'Tamara.Unity.Winters@dtaa.com',
#        'Kaden.Ross.Marsh@dtaa.com', 'Naida.Marny.Garrison@dtaa.com',
#        'Chester.Fitzgerald.Randolph@dtaa.com',
#        'Amber.Rhonda.Howe@dtaa.com', 'Avram.Malcolm.Carey@dtaa.com',
#        'Quin.Colette.Fuller@dtaa.com', 'Haley.Ori.Justice@dtaa.com',
#        'Cherokee.Bree.Kaufman@dtaa.com', 'Mallory.Echo.Beard@dtaa.com',
#        'Brett.Cade.Estes@dtaa.com', 'Sade.Myra.Fitzgerald@dtaa.com',
#        'Alden.Gary.Puckett@dtaa.com', 'Anne.Riley.Sloan@dtaa.com',
#        'Denton.Ahmed.Hoffman@dtaa.com', 'Guy.Felix.Mckay@dtaa.com',
#        'Destiny.Mary.Hill@dtaa.com', 'Nicolas.Arsenio.Burke@dtaa.com',
#        'Adena.Guinevere.Diaz@dtaa.com', 'Noelani.Galena.Fields@dtaa.com',
#        'Clayton.Rudyard.Charles@dtaa.com', 'Vance.Curran.Payne@dtaa.com',
#        'Seth.George.Walsh@dtaa.com', 'Kalia.Emerald.Sanford@dtaa.com',
#        'Felix.Justin.Stevens@dtaa.com', 'Myles.Lee.Gardner@dtaa.com',
#        'Plato.Brennan.Gross@dtaa.com', 'Benjamin.Hilel.Knight@dtaa.com',
#        'Nicole.Mara.Wilkinson@dtaa.com',
#        'Hayden.Brennan.Browning@dtaa.com',
#        'Casey.Ezekiel.Pollard@dtaa.com', 'Hollee.Lucy.Shaw@dtaa.com',
#        'Octavius.Brett.Cox@dtaa.com', 'Colin.Dennis.Holman@dtaa.com',
#        'Caldwell.Lance.Cardenas@dtaa.com', 'Maxwell.Cody.Glass@dtaa.com',
#        'Kitra.Priscilla.Wells@dtaa.com',
#        'Melanie.Juliet.Lindsey@dtaa.com',
#        'Marshall.Ciaran.Jacobson@dtaa.com',
#        'Graiden.Acton.Casey@dtaa.com', 'Justina.Maia.Benjamin@dtaa.com',
#        'Rina.Charity.Graham@dtaa.com', 'Regan.Kirestin.Frye@dtaa.com',
#        'Rylee.Keelie.Reilly@dtaa.com', 'Doris.Madeline.Mclean@dtaa.com',
#        'Keely.Maris.Todd@dtaa.com', 'Ryan.Elmo.Webster@dtaa.com',
#        'Micah.Harlan.Hopper@dtaa.com', 'Mechelle.Fiona.Randolph@dtaa.com',
#        'Roth.Cole.Mueller@dtaa.com', 'Rachel.Denise.Horn@dtaa.com',
#        'Jin.Marvin.Tyler@dtaa.com', 'Alika.Odessa.Hammond@dtaa.com',
#        'Ashton.Ignatius.Roberson@dtaa.com', 'Alexa.Ruby.Dillon@dtaa.com',
#        'Elijah.Ciaran.Taylor@dtaa.com',
#        'Jonathan.Theodore.Rollins@dtaa.com',
#        'Amena.Joelle.Burton@dtaa.com', 'Laurel.Amanda.Middleton@dtaa.com',
#        'Alfreda.Gretchen.Clarke@dtaa.com',
#        'William.Aladdin.Schmidt@dtaa.com', 'Mira.Pamela.Owen@dtaa.com',
#        'Brendan.Basil.Donovan@dtaa.com', 'Benedict.Oscar.James@dtaa.com',
#        'Sawyer.Josiah.Britt@dtaa.com', 'Honorato.Laith.Jennings@dtaa.com',
#        'Stone.Forrest.Keith@dtaa.com', 'Nevada.Daria.Landry@dtaa.com',
#        'Wendy.Germaine.Lawson@dtaa.com', 'Galvin.Jordan.Parsons@dtaa.com',
#        'Isadora.Zenia.Shelton@dtaa.com', 'Dustin.Ciaran.Griffin@dtaa.com',
#        'Jerry.Arthur.Roberts@dtaa.com',
#        'September.Danielle.Yang@dtaa.com',
#        'Tanner.Keefe.Knowles@dtaa.com',
#        'Brynne.Cassandra.Bartlett@dtaa.com',
#        'David.Davis.Blankenship@dtaa.com',
#        'Uta.Simone.Middleton@dtaa.com', 'Hilel.Colt.Rush@dtaa.com',
#        'Ian.Donovan.Gordon@dtaa.com', 'Ruby.Britanni.Haley@dtaa.com',
#        'Brendan.Perry.Hensley@dtaa.com', 'Aristotle.Joseph.Holt@dtaa.com',
#        'Susan.Kyra.Carpenter@dtaa.com', 'Dennis.Rahim.Hammond@dtaa.com',
#        'Velma.Evelyn.Lara@dtaa.com', 'Katell.Venus.Tran@dtaa.com',
#        'Macaulay.Kevin.Rocha@dtaa.com', 'Aurelia.Minerva.Vargas@dtaa.com',
#        'Xandra.Lila.Knight@dtaa.com', 'Finn.Kaden.Fernandez@dtaa.com',
#        'Maggie.Ria.Hurst@dtaa.com', 'Chaney.Grady.Pearson@dtaa.com',
#        'Keely.Adria.Rocha@dtaa.com', 'Demetrius.Stone.Mendoza@dtaa.com',
#        'Branden.Abdul.Avery@dtaa.com',
#        'Ayanna.Shelly.Villarreal@dtaa.com',
#        'Doris.Wynne.Cervantes@dtaa.com', 'Hadassah.Regan.King@dtaa.com',
#        'Connor.Basil.Ortega@dtaa.com', 'Bo.Cameron.Mccormick@dtaa.com',
#        'Selma.Lisandra.Little@dtaa.com', 'Marvin.Eric.Travis@dtaa.com',
#        'Hammett.Zahir.Craft@dtaa.com', 'Vivian.Amaya.Giles@dtaa.com',
#        'Virginia.Yeo.Vaughn@dtaa.com',
#        'Trevor.Benjamin.Delacruz@dtaa.com',
#        'Glenna.Yvette.Daniel@dtaa.com', 'Rhea.Shafira.Collins@dtaa.com',
#        'Clark.Alexander.English@dtaa.com',
#        'Ursula.Georgia.Harding@dtaa.com',
#        'Jonathan.Aubrey.Lopez@dtaa.com',
#        'Nicolas.Buckminster.Perry@dtaa.com',
#        'MacKenzie.Cameran.Hahn@dtaa.com', 'Alexa.Octavia.Dotson@dtaa.com',
#        'Victoria.Regan.Fisher@dtaa.com', 'Hilda.Deborah.Hopper@dtaa.com',
#        'Brittany.Cynthia.Phelps@dtaa.com',
#        'Lani.Wyoming.Osborne@dtaa.com',
#        'Scarlet.Noelle.Patterson@dtaa.com', 'Rogan.Luke.Crosby@dtaa.com',
#        'Beverly.Melinda.Cain@dtaa.com', 'Amir.Damian.Rosario@dtaa.com',
#        'Nash.Blair.Best@dtaa.com', 'Nyssa.Sara.Tyler@dtaa.com',
#        'Rinah.Rana.Estrada@dtaa.com', 'Sade.Hillary.Garrett@dtaa.com',
#        'Tamara.Tara.Page@dtaa.com', 'Jocelyn.Nyssa.Wooten@dtaa.com',
#        'Leo.Edward.Finch@dtaa.com', 'Colin.Len.Snow@dtaa.com',
#        'Ruby.Brielle.Hatfield@dtaa.com', 'Regina.Piper.Mcclain@dtaa.com',
#        'Charles.Beck.Hutchinson@dtaa.com',
#        'Meghan.Sophia.Dudley@dtaa.com', 'Karyn.Janna.Rich@dtaa.com',
#        'Vladimir.Beck.Becker@dtaa.com', 'Lilah.Piper.Mccarthy@dtaa.com',
#        'Kalia.Allegra.Harvey@dtaa.com', 'Wing.Marsden.Pope@dtaa.com',
#        'Jamalia.Shelly.Nixon@dtaa.com',
#        'Talon.Benjamin.Nicholson@dtaa.com',
#        'Kaitlin.Sylvia.Bush@dtaa.com', 'Angela.Emerald.Ashley@dtaa.com',
#        'Tarik.Edan.Carter@dtaa.com', 'Dara.Maisie.Sloan@dtaa.com',
#        'Shelly.Quynn.Baldwin@dtaa.com',
#        'Kendall.Isabella.Castro@dtaa.com', 'Hector.Beck.Shaw@dtaa.com',
#        'Kathleen.Nevada.Holden@dtaa.com', 'Emma.Tamara.Kaufman@dtaa.com',
#        'Chelsea.Martha.Lyons@dtaa.com', 'Hayfa.Phyllis.Leon@dtaa.com',
#        'Roanna.Leigh.Jensen@dtaa.com', 'Elmo.Leroy.Roberts@dtaa.com',
#        'Timon.William.Gallagher@dtaa.com', 'Wing.Brady.Morse@dtaa.com',
#        'Bertha.Zia.Vinson@dtaa.com', 'Preston.Quentin.Schultz@dtaa.com',
#        'Benjamin.Quinlan.Kidd@dtaa.com', 'Mara.Anne.George@dtaa.com',
#        'Lucy.Irene.Payne@dtaa.com', 'Rahim.Ashton.Copeland@dtaa.com',
#        'Cara.Uta.Herman@dtaa.com', 'Brielle.Jeanette.Stark@dtaa.com',
#        'Virginia.Zorita.Sherman@dtaa.com',
#        'Jillian.Sopoline.Ball@dtaa.com', 'Maile.Deborah.Merrill@dtaa.com',
#        'Karyn.Yeo.Mckay@dtaa.com', 'Stephen.Axel.Holmes@dtaa.com',
#        'Katelyn.Cameron.Rivera@dtaa.com', 'Paula.Yoshi.Talley@dtaa.com',
#        'Bianca.Xaviera.Joyce@dtaa.com', 'Kaseem.Camden.English@dtaa.com',
#        'Vielka.Nevada.Sanchez@dtaa.com', 'Sybil.Sonya.Davis@dtaa.com',
#        'Callum.Forrest.Page@dtaa.com', 'Sonia.Veda.Mclean@dtaa.com',
#        'Xavier.Theodore.Mckinney@dtaa.com',
#        'Charity.Kylie.Haynes@dtaa.com',
#        'Herman.Thaddeus.Elliott@dtaa.com',
#        'Montana.Janna.Sanchez@dtaa.com', 'Melodie.April.Pitts@dtaa.com',
#        'Serina.Serena.Rosales@dtaa.com', 'Eagan.William.Wright@dtaa.com',
#        'Bruno.Mannix.Trujillo@dtaa.com', 'Olivia.Jaquelyn.Bush@dtaa.com',
#        'Arden.Cooper.Macdonald@dtaa.com',
#        'Carlos.Harrison.Gordon@dtaa.com',
#        'Richard.Hedley.Norman@dtaa.com', 'Destiny.Nell.Glass@dtaa.com',
#        'John.Drake.Vinson@dtaa.com', 'Lance.Uriel.Garcia@dtaa.com',
#        'Tate.Kennedy.Logan@dtaa.com', 'Lillian.Quemby.Franklin@dtaa.com',
#        'Dora.Ivy.Vasquez@dtaa.com', 'Callum.Theodore.Pittman@dtaa.com',
#        'Callum.Ryder.Mercer@dtaa.com',
#        'Madonna.Quintessa.Odonnell@dtaa.com',
#        'Ashton.Wing.Norman@dtaa.com', 'Claire.Angelica.Wooten@dtaa.com',
#        'Rana.Aubrey.Whitney@dtaa.com', 'Renee.Clio.Moody@dtaa.com',
#        'Fitzgerald.Gray.Woodward@dtaa.com',
#        'Jelani.Rogan.Simmons@dtaa.com',
#        'William.Alec.Fitzpatrick@dtaa.com',
#        'Kenneth.Stewart.Horn@dtaa.com',
#        'Constance.Glenna.Sanford@dtaa.com',
#        'Abra.Lenore.Puckett@dtaa.com', 'Justin.Evan.Callahan@dtaa.com',
#        'Christopher.Upton.Doyle@dtaa.com', 'Dale.Chester.Bruce@dtaa.com',
#        'Albert.Paki.Hines@dtaa.com', 'Cairo.Alan.Smith@dtaa.com',
#        'Angela.Carolyn.Johns@dtaa.com', 'Emerson.Griffin.Wood@dtaa.com',
#        'Warren.Fletcher.Ramirez@dtaa.com',
#        'Thaddeus.Graiden.Knight@dtaa.com',
#        'Cara.Genevieve.Wiggins@dtaa.com', 'Reece.Quentin.Dixon@dtaa.com',
#        'Thomas.Leo.Kemp@dtaa.com', 'Jonathan.Elton.Bernard@dtaa.com',
#        'Hyatt.Timothy.Lamb@dtaa.com', 'Malachi.Quamar.Maxwell@dtaa.com',
#        'Hashim.Daquan.Gillespie@dtaa.com',
#        'Catherine.Naomi.Mullins@dtaa.com', 'Cailin.Lunea.Haley@dtaa.com',
#        'Nissim.Myles.Beck@dtaa.com', 'Adara.Mary.Oneill@dtaa.com',
#        'Bruno.Troy.Neal@dtaa.com', 'Mannix.Walter.Barrera@dtaa.com',
#        'Damon.Alvin.James@dtaa.com', 'Mohammad.Orson.Gutierrez@dtaa.com',
#        'Ryan.Amery.Garrett@dtaa.com', 'Deanna.Kylie.Hyde@dtaa.com',
#        'Alma.Christine.Copeland@dtaa.com',
#        'Shoshana.Jaden.Marks@dtaa.com', 'Michael.Malik.Odonnell@dtaa.com',
#        'Gareth.Vernon.Hopper@dtaa.com', 'Robert.Ronan.Mcmillan@dtaa.com',
#        'Ezekiel.Nero.Weeks@dtaa.com', 'Jael.Deborah.Richardson@dtaa.com',
#        'Ferris.Ezra.Delacruz@dtaa.com', 'Chase.Luke.Francis@dtaa.com',
#        'Genevieve.Olga.Ingram@dtaa.com', 'Maggy.Maryam.Newman@dtaa.com',
#        'Oren.Kadeem.Jarvis@dtaa.com', 'Nina.Sasha.Bolton@dtaa.com',
#        'Isabelle.Blair.Burnett@dtaa.com', 'Doris.Sierra.Arnold@dtaa.com',
#        'Thor.Jacob.Luna@dtaa.com', 'Beverly.Medge.Salas@dtaa.com',
#        'Brielle.Wilma.Hood@dtaa.com', 'Eleanor.Nora.Stafford@dtaa.com',
#        'Basil.Charles.Nguyen@dtaa.com', 'Wesley.Isaiah.Hansen@dtaa.com',
#        'Eden.Angelica.Dejesus@dtaa.com', 'Molly.Eve.Bauer@dtaa.com',
#        'Myra.Rebekah.Mcclain@dtaa.com', 'Imani.Martha.Sharpe@dtaa.com',
#        'Basil.Nathan.Thornton@dtaa.com', 'Madeson.Kiona.Holmes@dtaa.com',
#        'Jessamine.Jeanette.Pitts@dtaa.com',
#        'Rooney.Leonard.Rush@dtaa.com', 'Joseph.Micah.Hahn@dtaa.com',
#        'Shelley.Tatum.David@dtaa.com', 'Axel.Oleg.Mills@dtaa.com',
#        'Leah.Nina.Riggs@dtaa.com', 'Tarik.Benjamin.Stokes@dtaa.com',
#        'Adria.Montana.Mcfadden@dtaa.com',
#        'MacKensie.Amelia.Goff@dtaa.com',
#        'Jocelyn.Deanna.Puckett@dtaa.com',
#        'Alexandra.Danielle.Frost@dtaa.com',
#        'Tyrone.Zephania.Fisher@dtaa.com',
#        'Elliott.Bernard.Suarez@dtaa.com',
#        'Deborah.Rowan.Frederick@dtaa.com', 'Ezra.Cain.Dickerson@dtaa.com',
#        'Stella.Carolyn.Church@dtaa.com',
#        'Prescott.Arden.Sandoval@dtaa.com', 'Naida.Heather.Duran@dtaa.com',
#        'Ifeoma.Clementine.Rodgers@dtaa.com',
#        'Jonathan.Chaim.Good@dtaa.com', 'Farrah.Nelle.Daugherty@dtaa.com',
#        'Thomas.Dale.Gilbert@dtaa.com', 'Thor.Allistair.Perez@dtaa.com',
#        'Hillary.Dara.Ashley@dtaa.com', 'Elliott.Slade.Garcia@dtaa.com',
#        'Ferdinand.Kendall.Carter@dtaa.com',
#        'Chaim.Macaulay.Roth@dtaa.com', 'Velma.Autumn.Klein@dtaa.com',
#        'Dominique.Hollee.Pratt@dtaa.com', 'Tamara.Gisela.Bowers@dtaa.com',
#        'Catherine.Deborah.White@dtaa.com',
#        'Stephanie.Madaline.Knapp@dtaa.com',
#        'Meghan.Eliana.England@dtaa.com', 'Neil.Judah.Holman@dtaa.com',
#        'Garth.Albert.Salinas@dtaa.com', 'Nichole.Hope.Harrison@dtaa.com',
#        'Briar.Brenna.Thomas@dtaa.com', 'James.Keefe.Schmidt@dtaa.com',
#        'Ava.Wyoming.Robertson@dtaa.com', 'Cynthia.Katelyn.Beach@dtaa.com',
#        'Vance.Cadman.Jenkins@dtaa.com', 'Dawn.Signe.William@dtaa.com',
#        'Yoshi.Raven.Blair@dtaa.com', 'Blaine.Fallon.Moran@dtaa.com',
#        'Mara.Lara.Patton@dtaa.com', 'Alika.Hayley.Simpson@dtaa.com',
#        'Bevis.Oliver.Randolph@dtaa.com', 'Carol.Dakota.Nunez@dtaa.com',
#        'Sonya.Angela.Leach@dtaa.com', 'Adele.Julie.Yates@dtaa.com',
#        'Keith.Dieter.Vang@dtaa.com', 'Jamalia.Lisandra.Kane@dtaa.com',
#        'Naida.Robin.Terrell@dtaa.com', 'Xandra.Celeste.Riley@dtaa.com',
#        'Jeanette.Veronica.Baird@dtaa.com', 'Carol.May.Greer@dtaa.com',
#        'Nadine.Ulla.Reyes@dtaa.com', 'Laura.Jane.Mcknight@dtaa.com',
#        'Keane.Stephen.Howe@dtaa.com', 'Leila.Moana.Beck@dtaa.com',
#        'Cairo.Hedley.Gordon@dtaa.com', 'Xerxes.Martena.Velez@dtaa.com',
#        'Hedda.Guinevere.Humphrey@dtaa.com',
#        'Carl.Chancellor.Richard@dtaa.com', 'Quin.Macy.Woodard@dtaa.com',
#        'Nomlanga.Noel.Mullen@dtaa.com', 'Lara.Adria.Hopkins@dtaa.com',
#        'Beau.Joshua.Webb@dtaa.com', 'Tanner.Marsden.Chavez@dtaa.com',
#        'Rina.Phoebe.May@dtaa.com', 'Orli.Tamara.Wade@dtaa.com',
#        'John.Brock.Bradshaw@dtaa.com', 'Marah.Iona.Watson@dtaa.com',
#        'Phelan.Randall.Mayo@dtaa.com', 'Deanna.Zelda.Buck@dtaa.com',
#        'Lance.Branden.Donaldson@dtaa.com',
#        'Barrett.Howard.Beasley@dtaa.com', 'Stephen.Harlan.Long@dtaa.com',
#        'Olivia.Ruby.Clayton@dtaa.com', 'Xena.Olga.Delaney@dtaa.com',
#        'Zachery.Ian.Flores@dtaa.com', 'Lynn.Fredericka.Bonner@dtaa.com',
#        'Hayfa.Virginia.Edwards@dtaa.com',
#        'Farrah.Montana.Hoover@dtaa.com', 'Brody.Adam.Mcdonald@dtaa.com',
#        'Erica.Shelly.Mcmahon@dtaa.com', 'Yvette.Holly.Landry@dtaa.com',
#        'Yoshio.Colton.Rosa@dtaa.com', 'India.Nerea.Lang@dtaa.com',
#        'Salvador.Thomas.Bass@dtaa.com', 'Elizabeth.Leah.Byrd@dtaa.com',
#        'Abbot.Raja.Valdez@dtaa.com', 'Jena.Keely.Ramirez@dtaa.com',
#        'Yael.Carissa.Montgomery@dtaa.com',
#        'Robert.Yasir.Cervantes@dtaa.com',
#        'Marshall.Sloane.Cherry@dtaa.com', 'Wallace.Beau.Molina@dtaa.com',
#        'Jenna.Sybil.Goodwin@dtaa.com', 'Harding.Darius.Bowman@dtaa.com',
#        'Aquila.Bruce.Webster@dtaa.com', 'Gisela.Alana.Griffin@dtaa.com',
#        'Rhea.Odette.Vazquez@dtaa.com',
#        'Fitzgerald.William.Torres@dtaa.com',
#        'Chaim.Preston.Mcmillan@dtaa.com', 'Doris.Sandra.Parks@dtaa.com',
#        'Faith.Quail.Justice@dtaa.com', 'Randall.Ivan.Compton@dtaa.com',
#        'Zelda.Ariana.Boone@dtaa.com', 'Emmanuel.Xenos.Norman@dtaa.com',
#        'Sawyer.Hilel.Garcia@dtaa.com', 'Herman.Zahir.Mcclain@dtaa.com',
#        'Clio.Hyacinth.Kelly@dtaa.com', 'Jeremy.Chester.Rocha@dtaa.com',
#        'Maggie.Wynne.Simon@dtaa.com', 'Callie.Zia.Mcfarland@dtaa.com',
#        'Hyacinth.Tana.Molina@dtaa.com', 'Sonia.Alika.Blair@dtaa.com',
#        'Quinn.Arden.Haynes@dtaa.com', 'Cadman.Alexander.Tillman@dtaa.com',
#        'Edward.Arden.Newman@dtaa.com',
#        'Theodore.Graiden.Fischer@dtaa.com', 'Taylor.Grant.Duran@dtaa.com',
#        'Benjamin.Elton.Haynes@dtaa.com', 'Holmes.Malachi.Baker@dtaa.com',
#        'Zephania.William.Fowler@dtaa.com',
#        'Mechelle.Yolanda.Hopkins@dtaa.com',
#        'Talon.Seth.Mccullough@dtaa.com', 'Merrill.Jasper.Peters@dtaa.com',
#        'Casey.Leo.Ward@dtaa.com', 'Peter.Wyatt.Landry@dtaa.com',
#        'Stuart.Avram.Cain@dtaa.com', 'Ivor.Avram.Mccullough@dtaa.com',
#        'Rachel.Kelsie.Puckett@dtaa.com', 'Naida.Maya.Velasquez@dtaa.com',
#        'Vladimir.Garrison.Jackson@dtaa.com', 'Kane.Damian.Knox@dtaa.com',
#        'Bell.Mona.Carroll@dtaa.com', 'Jolie.Sandra.Booth@dtaa.com',
#        'Deborah.Sarah.Zimmerman@dtaa.com', 'Lucian.Phillip.Beck@dtaa.com',
#        'Bethany.Eden.Cline@dtaa.com', 'Lael.Octavia.Serrano@dtaa.com',
#        'Dakota.Jennifer.Christian@dtaa.com',
#        'Wendy.Pandora.Harmon@dtaa.com', 'Hamish.Griffin.Decker@dtaa.com',
#        'Sopoline.Gillian.Burnett@dtaa.com', 'Hope.Illiana.Bowen@dtaa.com',
#        'Yasir.Thomas.Bruce@dtaa.com',
#        'Dorothy.Lisandra.Williams@dtaa.com',
#        'Dustin.John.Sullivan@dtaa.com', 'Lillian.Jane.Floyd@dtaa.com',
#        'Amber.Skyler.Booth@dtaa.com', 'Rana.Olivia.Benton@dtaa.com',
#        'Yen.Kiona.Booth@dtaa.com', 'Vladimir.George.Mayer@dtaa.com',
#        'Lillian.Nerea.Burnett@dtaa.com',
#        'Lucius.Dexter.Cummings@dtaa.com', 'Callie.Belle.Lowe@dtaa.com',
#        'Rhonda.Kai.Gray@dtaa.com', 'Dominique.Yuri.Clark@dtaa.com',
#        'Cameran.Ebony.Briggs@dtaa.com', 'Axel.Kamal.Cross@dtaa.com',
#        'Lareina.Xyla.Sampson@dtaa.com', 'Wyatt.Tucker.Pierce@dtaa.com',
#        'Allegra.Stacy.Clarke@dtaa.com', 'Roth.Dante.Floyd@dtaa.com',
#        'Moana.Susan.Wilkerson@dtaa.com', 'Garrett.Steven.Witt@dtaa.com',
#        'Hamilton.Hoyt.Small@dtaa.com', 'Ora.Jada.Beard@dtaa.com',
#        'Alden.Alfonso.Wilder@dtaa.com', 'Drew.Aaron.Massey@dtaa.com',
#        'Paul.Jameson.Bruce@dtaa.com', 'Reuben.Lewis.Sellers@dtaa.com',
#        'Clio.Jennifer.Wade@dtaa.com', 'Karyn.Shellie.Mitchell@dtaa.com',
#        'Wing.Zachery.Head@dtaa.com', 'Naida.Aline.Parsons@dtaa.com',
#        'Reese.Driscoll.Duncan@dtaa.com', 'Gannon.William.Brady@dtaa.com',
#        'David.Dalton.Riggs@dtaa.com',
#        'Kenyon.Harrison.Valentine@dtaa.com', 'Hunter.John.Kane@dtaa.com',
#        'Xander.Lev.Carson@dtaa.com', 'Desiree.Jolie.Pittman@dtaa.com',
#        'Jillian.Rama.Garner@dtaa.com', 'Adam.Nero.Chen@dtaa.com',
#        'Kato.Lyle.Rosa@dtaa.com', 'Kim.Kirsten.Barber@dtaa.com',
#        'Chandler.Aladdin.Hahn@dtaa.com',
#        'Kathleen.Imogene.Chandler@dtaa.com', 'Jane.Yeo.Clark@dtaa.com',
#        'Ulric.Blaine.Harvey@dtaa.com', 'Aidan.Keith.Gay@dtaa.com',
#        'Marny.Kelsey.Hudson@dtaa.com', 'Mercedes.Ariel.Moreno@dtaa.com',
#        'Harlan.Kadeem.Carpenter@dtaa.com',
#        'Quemby.Britanni.Mccoy@dtaa.com', 'Keegan.Yardley.Knox@dtaa.com',
#        'Iliana.Nayda.Chavez@dtaa.com', 'Wang.Reese.Leach@dtaa.com',
#        'Kiona.Leandra.Barlow@dtaa.com', 'Virginia.Paloma.Pace@dtaa.com',
#        'Ralph.Nathaniel.Bowers@dtaa.com', 'Larissa.Cleo.Carter@dtaa.com',
#        'Larissa.Ori.Hayes@dtaa.com', 'Bruce.Lee.Mullins@dtaa.com',
#        'Rose.Gretchen.Oneil@dtaa.com', 'Rajah.Hammett.Marks@dtaa.com',
#        'Wynne.Tamekah.Black@dtaa.com', 'Deborah.Cynthia.Wooten@dtaa.com',
#        'Kenyon.Channing.Horton@dtaa.com',
#        'Emerald.Anastasia.Leach@dtaa.com',
#        'Alice.Jessica.Dodson@dtaa.com', 'Noel.Mari.Guerra@dtaa.com',
#        'Georgia.Kathleen.Talley@dtaa.com',
#        'Christine.Zia.Keller@dtaa.com',
#        'Francesca.Miranda.Beasley@dtaa.com'], dtype=object)

# %%
display(len(df_email['from'].unique()))
# Out:
# 1000

# %%
display(len(df_user_email['employee_name']))
display(len(df_user_email['email']))
# Out:
# 13868
# 13868

# %%
display(len(df_user_email['email'].unique()))
# Out:
# 1000

# %%
df_user_email = df_user_email.drop_duplicates()

# %%
email_copy = df_email.copy()

# %%
user_email_copy = df_user_email.copy()

# %%
email_user_merge = pd.merge(email_copy,user_email_copy,how="outer",indicator=True,left_on='from',right_on='email')
email_user_merge
# Out:
#                                id                 date  \
# 0        {B7K5-M2PZ77HC-5876WFKM}  03/11/2011 13:54:54
# 1        {H9L1-H4LU70FP-9150ZBSD}  08/09/2010 13:20:11
# 2        {G7L2-R2RP98FU-4313WANF}  07/29/2010 17:26:24
# 3        {N6B6-I8GJ06AN-9689JWSV}  05/28/2010 13:18:27
# 4        {J3O0-M3ZO03RV-5036OYMA}  05/05/2010 16:57:59
# ...                           ...                  ...
# 1580075  {Q6S4-P4YI17LY-8678FRZU}  06/18/2010 16:40:29
# 1580076  {P5J8-S1LC03UE-6425SUCH}  05/28/2010 13:53:52
# 1580077  {A5P7-M4PQ40HM-7454ISAR}  04/28/2010 12:21:08
# 1580078  {Z3Z9-R6IA55WX-6780DLHG}  05/25/2010 16:01:54
# 1580079  {M9P0-W0DA99CV-9046RUDG}  03/31/2010 13:50:40
#
#                                                         to  \
# 0        Adena.Guinevere.Diaz@dtaa.com;Karleigh.Lareina...
# 1        Branden.Kirk.Acevedo@dtaa.com;Hollee.Noelle.Wa...
# 2                           Doris.Wynne.Cervantes@dtaa.com
# 3        Fredericka.Martina.Lynn@dtaa.com;Phoebe.Tatum....
# 4        India.Nerea.Lang@dtaa.com;Branden.Kirk.Acevedo...
# ...                                                    ...
# 1580075                    Plato.Axel.Terrell@raytheon.com
# 1580076                   Deborah.Rowan.Frederick@dtaa.com
# 1580077                         Bruce.Lee.Mullins@dtaa.com
# 1580078                     Lenore.Teegan.Campos@yahoo.com
# 1580079                  Oleg.Benjamin.Donovan@comcast.net
#
#                                        from   size  attachments  \
# 0             Cameron.Meghan.Sloan@dtaa.com  48940            0
# 1             Cameron.Meghan.Sloan@dtaa.com  30270            0
# 2             Cameron.Meghan.Sloan@dtaa.com  39065            1
# 3             Cameron.Meghan.Sloan@dtaa.com  50120            0
# 4             Cameron.Meghan.Sloan@dtaa.com  27050            0
# ...                                     ...    ...          ...
# 1580075  Francesca.Miranda.Beasley@dtaa.com  38873            0
# 1580076  Francesca.Miranda.Beasley@dtaa.com  29523            0
# 1580077  Francesca.Miranda.Beasley@dtaa.com  23028            0
# 1580078  Francesca.Miranda.Beasley@dtaa.com  25210            0
# 1580079  Francesca.Miranda.Beasley@dtaa.com  37346            0
#
#                                                    content  \
# 0        dean 423 columns3 meandered blackburn ruabon b...
# 1        erbert florance dudgeon zingari 2592 topping t...
# 2        dontay turf terps jamari wac jaekle boise terr...
# 3        spartiate ganteaume souverain tippoo aquilon b...
# 4        rugrats schlomos rugrats minka muzquiz schlomo...
# ...                                                    ...
# 1580075  fishbone octopus skye chutzpah latter mofo chi...
# 1580076  couldve sobriety meits mosh qualms flea kiedis...
# 1580077  akinetic neurodegenerative symptoms symptoms a...
# 1580078  cedeo varitek sox bats gretchen zelasko ortiz ...
# 1580079  spira sidequests sidequests blitzball sideques...
#
#                      employee_name  user_id  \
# 0             Cameron Meghan Sloan  CMS0535
# 1             Cameron Meghan Sloan  CMS0535
# 2             Cameron Meghan Sloan  CMS0535
# 3             Cameron Meghan Sloan  CMS0535
# 4             Cameron Meghan Sloan  CMS0535
# ...                            ...      ...
# 1580075  Francesca Miranda Beasley  FMB0794
# 1580076  Francesca Miranda Beasley  FMB0794
# 1580077  Francesca Miranda Beasley  FMB0794
# 1580078  Francesca Miranda Beasley  FMB0794
# 1580079  Francesca Miranda Beasley  FMB0794
#
#                                       email _merge
# 0             Cameron.Meghan.Sloan@dtaa.com   both
# 1             Cameron.Meghan.Sloan@dtaa.com   both
# 2             Cameron.Meghan.Sloan@dtaa.com   both
# 3             Cameron.Meghan.Sloan@dtaa.com   both
# 4             Cameron.Meghan.Sloan@dtaa.com   both
# ...                                     ...    ...
# 1580075  Francesca.Miranda.Beasley@dtaa.com   both
# 1580076  Francesca.Miranda.Beasley@dtaa.com   both
# 1580077  Francesca.Miranda.Beasley@dtaa.com   both
# 1580078  Francesca.Miranda.Beasley@dtaa.com   both
# 1580079  Francesca.Miranda.Beasley@dtaa.com   both
#
# [1580080 rows x 11 columns]

# %%
# email_user_merge['_merge'].unique()
# email_user_merge.isna().sum()

# %%
# del email_user_merge['email']
# del email_user_merge['_merge']
del_columns = ['email','_merge','attachments','content','from']
email_user_merge.drop(columns=del_columns,inplace=True)

email_user_merge
# Out:
#                                id                 date  \
# 0        {B7K5-M2PZ77HC-5876WFKM}  03/11/2011 13:54:54
# 1        {H9L1-H4LU70FP-9150ZBSD}  08/09/2010 13:20:11
# 2        {G7L2-R2RP98FU-4313WANF}  07/29/2010 17:26:24
# 3        {N6B6-I8GJ06AN-9689JWSV}  05/28/2010 13:18:27
# 4        {J3O0-M3ZO03RV-5036OYMA}  05/05/2010 16:57:59
# ...                           ...                  ...
# 1580075  {Q6S4-P4YI17LY-8678FRZU}  06/18/2010 16:40:29
# 1580076  {P5J8-S1LC03UE-6425SUCH}  05/28/2010 13:53:52
# 1580077  {A5P7-M4PQ40HM-7454ISAR}  04/28/2010 12:21:08
# 1580078  {Z3Z9-R6IA55WX-6780DLHG}  05/25/2010 16:01:54
# 1580079  {M9P0-W0DA99CV-9046RUDG}  03/31/2010 13:50:40
#
#                                                         to   size  \
# 0        Adena.Guinevere.Diaz@dtaa.com;Karleigh.Lareina...  48940
# 1        Branden.Kirk.Acevedo@dtaa.com;Hollee.Noelle.Wa...  30270
# 2                           Doris.Wynne.Cervantes@dtaa.com  39065
# 3        Fredericka.Martina.Lynn@dtaa.com;Phoebe.Tatum....  50120
# 4        India.Nerea.Lang@dtaa.com;Branden.Kirk.Acevedo...  27050
# ...                                                    ...    ...
# 1580075                    Plato.Axel.Terrell@raytheon.com  38873
# 1580076                   Deborah.Rowan.Frederick@dtaa.com  29523
# 1580077                         Bruce.Lee.Mullins@dtaa.com  23028
# 1580078                     Lenore.Teegan.Campos@yahoo.com  25210
# 1580079                  Oleg.Benjamin.Donovan@comcast.net  37346
#
#                      employee_name  user_id
# 0             Cameron Meghan Sloan  CMS0535
# 1             Cameron Meghan Sloan  CMS0535
# 2             Cameron Meghan Sloan  CMS0535
# 3             Cameron Meghan Sloan  CMS0535
# 4             Cameron Meghan Sloan  CMS0535
# ...                            ...      ...
# 1580075  Francesca Miranda Beasley  FMB0794
# 1580076  Francesca Miranda Beasley  FMB0794
# 1580077  Francesca Miranda Beasley  FMB0794
# 1580078  Francesca Miranda Beasley  FMB0794
# 1580079  Francesca Miranda Beasley  FMB0794
#
# [1580080 rows x 6 columns]

# %%
columns_reindex = ['id', 'date', 'employee_name','user_id','to','size']
email_user_merge = email_user_merge[columns_reindex]
email_user_merge
# Out:
#                                id                 date  \
# 0        {B7K5-M2PZ77HC-5876WFKM}  03/11/2011 13:54:54
# 1        {H9L1-H4LU70FP-9150ZBSD}  08/09/2010 13:20:11
# 2        {G7L2-R2RP98FU-4313WANF}  07/29/2010 17:26:24
# 3        {N6B6-I8GJ06AN-9689JWSV}  05/28/2010 13:18:27
# 4        {J3O0-M3ZO03RV-5036OYMA}  05/05/2010 16:57:59
# ...                           ...                  ...
# 1580075  {Q6S4-P4YI17LY-8678FRZU}  06/18/2010 16:40:29
# 1580076  {P5J8-S1LC03UE-6425SUCH}  05/28/2010 13:53:52
# 1580077  {A5P7-M4PQ40HM-7454ISAR}  04/28/2010 12:21:08
# 1580078  {Z3Z9-R6IA55WX-6780DLHG}  05/25/2010 16:01:54
# 1580079  {M9P0-W0DA99CV-9046RUDG}  03/31/2010 13:50:40
#
#                      employee_name  user_id  \
# 0             Cameron Meghan Sloan  CMS0535
# 1             Cameron Meghan Sloan  CMS0535
# 2             Cameron Meghan Sloan  CMS0535
# 3             Cameron Meghan Sloan  CMS0535
# 4             Cameron Meghan Sloan  CMS0535
# ...                            ...      ...
# 1580075  Francesca Miranda Beasley  FMB0794
# 1580076  Francesca Miranda Beasley  FMB0794
# 1580077  Francesca Miranda Beasley  FMB0794
# 1580078  Francesca Miranda Beasley  FMB0794
# 1580079  Francesca Miranda Beasley  FMB0794
#
#                                                         to   size
# 0        Adena.Guinevere.Diaz@dtaa.com;Karleigh.Lareina...  48940
# 1        Branden.Kirk.Acevedo@dtaa.com;Hollee.Noelle.Wa...  30270
# 2                           Doris.Wynne.Cervantes@dtaa.com  39065
# 3        Fredericka.Martina.Lynn@dtaa.com;Phoebe.Tatum....  50120
# 4        India.Nerea.Lang@dtaa.com;Branden.Kirk.Acevedo...  27050
# ...                                                    ...    ...
# 1580075                    Plato.Axel.Terrell@raytheon.com  38873
# 1580076                   Deborah.Rowan.Frederick@dtaa.com  29523
# 1580077                         Bruce.Lee.Mullins@dtaa.com  23028
# 1580078                     Lenore.Teegan.Campos@yahoo.com  25210
# 1580079                  Oleg.Benjamin.Donovan@comcast.net  37346
#
# [1580080 rows x 6 columns]

# %%
email_user_merge['date'] = pd.to_datetime(email_user_merge['date'])

# %%
email_user_merge['time'] = email_user_merge['date'].dt.time
email_user_merge['hour'] = email_user_merge['date'].dt.hour

# %%
df_email_user = email_user_merge.copy()
df_email_user
# Out:
#                                id                date  \
# 0        {B7K5-M2PZ77HC-5876WFKM} 2011-03-11 13:54:54
# 1        {H9L1-H4LU70FP-9150ZBSD} 2010-08-09 13:20:11
# 2        {G7L2-R2RP98FU-4313WANF} 2010-07-29 17:26:24
# 3        {N6B6-I8GJ06AN-9689JWSV} 2010-05-28 13:18:27
# 4        {J3O0-M3ZO03RV-5036OYMA} 2010-05-05 16:57:59
# ...                           ...                 ...
# 1580075  {Q6S4-P4YI17LY-8678FRZU} 2010-06-18 16:40:29
# 1580076  {P5J8-S1LC03UE-6425SUCH} 2010-05-28 13:53:52
# 1580077  {A5P7-M4PQ40HM-7454ISAR} 2010-04-28 12:21:08
# 1580078  {Z3Z9-R6IA55WX-6780DLHG} 2010-05-25 16:01:54
# 1580079  {M9P0-W0DA99CV-9046RUDG} 2010-03-31 13:50:40
#
#                      employee_name  user_id  \
# 0             Cameron Meghan Sloan  CMS0535
# 1             Cameron Meghan Sloan  CMS0535
# 2             Cameron Meghan Sloan  CMS0535
# 3             Cameron Meghan Sloan  CMS0535
# 4             Cameron Meghan Sloan  CMS0535
# ...                            ...      ...
# 1580075  Francesca Miranda Beasley  FMB0794
# 1580076  Francesca Miranda Beasley  FMB0794
# 1580077  Francesca Miranda Beasley  FMB0794
# 1580078  Francesca Miranda Beasley  FMB0794
# 1580079  Francesca Miranda Beasley  FMB0794
#
#                                                         to   size      time  \
# 0        Adena.Guinevere.Diaz@dtaa.com;Karleigh.Lareina...  48940  13:54:54
# 1        Branden.Kirk.Acevedo@dtaa.com;Hollee.Noelle.Wa...  30270  13:20:11
# 2                           Doris.Wynne.Cervantes@dtaa.com  39065  17:26:24
# 3        Fredericka.Martina.Lynn@dtaa.com;Phoebe.Tatum....  50120  13:18:27
# 4        India.Nerea.Lang@dtaa.com;Branden.Kirk.Acevedo...  27050  16:57:59
# ...                                                    ...    ...       ...
# 1580075                    Plato.Axel.Terrell@raytheon.com  38873  16:40:29
# 1580076                   Deborah.Rowan.Frederick@dtaa.com  29523  13:53:52
# 1580077                         Bruce.Lee.Mullins@dtaa.com  23028  12:21:08
# 1580078                     Lenore.Teegan.Campos@yahoo.com  25210  16:01:54
# 1580079                  Oleg.Benjamin.Donovan@comcast.net  37346  13:50:40
#
#          hour
# 0          13
# 1          13
# 2          17
# 3          13
# 4          16
# ...       ...
# 1580075    16
# 1580076    13
# 1580077    12
# 1580078    16
# 1580079    13
#
# [1580080 rows x 8 columns]

# %%
df_email_user_stats = df_email_user.groupby('user_id')['time'].agg([min,max]).reset_index()
df_email_user_mode = df_email_user.groupby('user_id')['time'].agg(lambda x: x.value_counts().index[0]).reset_index()

# %%
df_email_user_mean = df_email_user.groupby('user_id')['hour'].mean().reset_index()
df_email_user_mean['hour'] = df_email_user_mean['hour'].astype(int)
df_email_user_mean['hour'] = pd.to_datetime(df_email_user_mean['hour'],format="%H").dt.time

# %%
df_email_user_mean
# Out:
#      user_id      hour
# 0    AAB0754  13:00:00
# 1    AAN0077  11:00:00
# 2    AAR0994  12:00:00
# 3    AAW0103  11:00:00
# 4    AAW0295  12:00:00
# ..       ...       ...
# 995  ZCL0920  12:00:00
# 996  ZIF0269  11:00:00
# 997  ZNF0145  12:00:00
# 998  ZWF0919  11:00:00
# 999  ZXA0931  11:00:00
#
# [1000 rows x 2 columns]

# %%
df_email_user_stats
# Out:
#      user_id       min       max
# 0    AAB0754  08:49:59  20:08:35
# 1    AAN0077  07:48:13  17:08:30
# 2    AAR0994  08:32:49  16:56:33
# 3    AAW0103  07:04:49  16:26:26
# 4    AAW0295  08:49:00  18:48:47
# ..       ...       ...       ...
# 995  ZCL0920  07:19:42  17:39:58
# 996  ZIF0269  07:08:40  16:20:17
# 997  ZNF0145  08:33:30  17:56:35
# 998  ZWF0919  07:23:16  17:28:27
# 999  ZXA0931  07:30:33  17:30:56
#
# [1000 rows x 3 columns]

# %%
df_size_per_email = df_email_user.groupby(['user_id'])['size'].agg(sum).reset_index()

# %%
df_size_per_email
# Out:
#      user_id      size
# 0    AAB0754  75208652
# 1    AAN0077  70947989
# 2    AAR0994  72770851
# 3    AAW0103  60216834
# 4    AAW0295   5769947
# ..       ...       ...
# 995  ZCL0920   7533194
# 996  ZIF0269  13665328
# 997  ZNF0145  81106203
# 998  ZWF0919   3837566
# 999  ZXA0931   7826516
#
# [1000 rows x 2 columns]

# %%
df_email_user_stats['mode'] = df_email_user_mode['time']
df_email_user_stats['mean'] = df_email_user_mean['hour']
df_email_user_stats['size'] = df_size_per_email['size']

# %%
df_email_user_stats
# Out:
#      user_id       min       max      mode      mean      size
# 0    AAB0754  08:49:59  20:08:35  18:30:07  13:00:00  75208652
# 1    AAN0077  07:48:13  17:08:30  09:13:28  11:00:00  70947989
# 2    AAR0994  08:32:49  16:56:33  11:35:00  12:00:00  72770851
# 3    AAW0103  07:04:49  16:26:26  12:57:46  11:00:00  60216834
# 4    AAW0295  08:49:00  18:48:47  09:35:10  12:00:00   5769947
# ..       ...       ...       ...       ...       ...       ...
# 995  ZCL0920  07:19:42  17:39:58  16:13:21  12:00:00   7533194
# 996  ZIF0269  07:08:40  16:20:17  13:22:13  11:00:00  13665328
# 997  ZNF0145  08:33:30  17:56:35  16:28:23  12:00:00  81106203
# 998  ZWF0919  07:23:16  17:28:27  09:04:14  11:00:00   3837566
# 999  ZXA0931  07:30:33  17:30:56  16:37:56  11:00:00   7826516
#
# [1000 rows x 6 columns]

# %%
df_email_user_stats_sec = df_email_user_stats

# %%
def dtt2timestamp(dtt):
  time_in_sec = (dtt.hour*60 + dtt.minute) * 60 + dtt.second
  return time_in_sec

# %%
min_ts = [dtt2timestamp(dtt) for dtt in df_email_user_stats_sec['min']]
max_ts = [dtt2timestamp(dtt) for dtt in df_email_user_stats_sec['max']]
mode_ts = [dtt2timestamp(dtt) for dtt in df_email_user_stats_sec['mode']]
mean_ts = [dtt2timestamp(dtt) for dtt in df_email_user_stats_sec['mean']]

# %%
df_email_user_stats_sec['min_ts'] = min_ts
df_email_user_stats_sec['max_ts'] = max_ts
df_email_user_stats_sec['mode_ts'] = mode_ts
df_email_user_stats_sec['mean_ts'] = mean_ts

# %%
df_email_user_stats_sec
# Out:
#      user_id       min       max      mode      mean      size  min_ts  \
# 0    AAB0754  08:49:59  20:08:35  18:30:07  13:00:00  75208652   31799
# 1    AAN0077  07:48:13  17:08:30  09:13:28  11:00:00  70947989   28093
# 2    AAR0994  08:32:49  16:56:33  11:35:00  12:00:00  72770851   30769
# 3    AAW0103  07:04:49  16:26:26  12:57:46  11:00:00  60216834   25489
# 4    AAW0295  08:49:00  18:48:47  09:35:10  12:00:00   5769947   31740
# ..       ...       ...       ...       ...       ...       ...     ...
# 995  ZCL0920  07:19:42  17:39:58  16:13:21  12:00:00   7533194   26382
# 996  ZIF0269  07:08:40  16:20:17  13:22:13  11:00:00  13665328   25720
# 997  ZNF0145  08:33:30  17:56:35  16:28:23  12:00:00  81106203   30810
# 998  ZWF0919  07:23:16  17:28:27  09:04:14  11:00:00   3837566   26596
# 999  ZXA0931  07:30:33  17:30:56  16:37:56  11:00:00   7826516   27033
#
#      max_ts  mode_ts  mean_ts
# 0     72515    66607    46800
# 1     61710    33208    39600
# 2     60993    41700    43200
# 3     59186    46666    39600
# 4     67727    34510    43200
# ..      ...      ...      ...
# 995   63598    58401    43200
# 996   58817    48133    39600
# 997   64595    59303    43200
# 998   62907    32654    39600
# 999   63056    59876    39600
#
# [1000 rows x 10 columns]

# %%
df_email_user_stats_sec.drop(['min','max','mode','mean'], axis=1, inplace=True)

# %%
df_email_user_stats_sec.dtypes
# Out:
# user_id    object
# size        int64
# min_ts      int64
# max_ts      int64
# mode_ts     int64
# mean_ts     int64
# dtype: object

# %%
email_stats = df_email_user_stats_sec.drop(['user_id'], axis = 1)

email_user_matrix = np.matrix(email_stats)

# %%
email_user_matrix
# Out:
# matrix([[75208652,    31799,    72515,    66607,    46800],
#         [70947989,    28093,    61710,    33208,    39600],
#         [72770851,    30769,    60993,    41700,    43200],
#         ...,
#         [81106203,    30810,    64595,    59303,    43200],
#         [ 3837566,    26596,    62907,    32654,    39600],
#         [ 7826516,    27033,    63056,    59876,    39600]])

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest

# %%
forest = IsolationForest(bootstrap=False, contamination= 0.1 , max_features=1.0,
        max_samples='auto', n_estimators=100, n_jobs=1, random_state=0,
        verbose=0)
forest.fit(email_user_matrix)
email_ascore = forest.decision_function(email_user_matrix)
email_ascore[:10]
# Out:
# array([0.00220861, 0.12871782, 0.10008317, 0.08821845, 0.08531647,
#        0.12071822, 0.07745106, 0.10195131, 0.11884773, 0.06384104])

# %%
df_email_result = pd.DataFrame()
df_email_result['user_id'] = df_email_user_stats_sec['user_id']
df_email_result['ascore'] = email_ascore
print(df_email_result)
# Out:
#      user_id    ascore
# 0    AAB0754  0.002209
# 1    AAN0077  0.128718
# 2    AAR0994  0.100083
# 3    AAW0103  0.088218
# 4    AAW0295  0.085316
# ..       ...       ...
# 995  ZCL0920  0.093554
# 996  ZIF0269  0.076153
# 997  ZNF0145  0.094833
# 998  ZWF0919  0.090579
# 999  ZXA0931  0.091363
#
# [1000 rows x 2 columns]

# %%
import pickle 
with open('../pkl/email_result.pkl','wb') as file :
  pickle.dump(forest, file)

# %%
#second Instance

# %%
# df_email_user_count = pd.read_csv(path+'user_email_count.csv')
# df_user_email_count
