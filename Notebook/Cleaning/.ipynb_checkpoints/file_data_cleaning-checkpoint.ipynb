# %% [markdown]
# # For File

# %%
import sys
sys.path.append('../Modules/')
import modules as md
import usermodules as um
import pandas as pd

# %%
df = md.ReadDataset('r4.2/file')

# %%
display(df.shape)
display(df.head())
display(df.tail())
# Out:
# (445581, 6)
#                          id                 date     user       pc  \
# 0  {L9G8-J9QE34VM-2834VDPB}  01/02/2010 07:23:14  MOH0273  PC-6699
# 1  {H0W6-L4FG38XG-9897XTEN}  01/02/2010 07:26:19  MOH0273  PC-6699
# 2  {M3Z0-O2KK89OX-5716MBIM}  01/02/2010 08:12:03  HPH0075  PC-2417
# 3  {E1I4-S4QS61TG-3652YHKR}  01/02/2010 08:17:00  HPH0075  PC-2417
# 4  {D4R7-E7JL45UX-0067XALT}  01/02/2010 08:24:57  HSB0196  PC-8001
#
#        filename                                            content
# 0  EYPC9Y08.doc  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...
# 1  N3LTSU3O.pdf  25-50-44-46-2D carpenters 25 landed strait dis...
# 2  D3D3WC9W.doc  D0-CF-11-E0-A1-B1-1A-E1 union 24 declined impo...
# 3  QCSW62YS.doc  D0-CF-11-E0-A1-B1-1A-E1 becoming period begin ...
# 4  AU75JV6U.jpg                                              FF-D8
#                               id                 date     user       pc  \
# 445576  {J2Q8-Z4UX02QT-2675RTJI}  05/16/2011 23:22:31  IBB0359  PC-3620
# ...

# %%
#conver to date time
um.convertToDateTime(df,'date')
# Out:
#                          id                date     user       pc  \
# 0  {L9G8-J9QE34VM-2834VDPB} 2010-01-02 07:23:14  MOH0273  PC-6699
# 1  {H0W6-L4FG38XG-9897XTEN} 2010-01-02 07:26:19  MOH0273  PC-6699
# 2  {M3Z0-O2KK89OX-5716MBIM} 2010-01-02 08:12:03  HPH0075  PC-2417
# 3  {E1I4-S4QS61TG-3652YHKR} 2010-01-02 08:17:00  HPH0075  PC-2417
# 4  {D4R7-E7JL45UX-0067XALT} 2010-01-02 08:24:57  HSB0196  PC-8001
#
#        filename                                            content
# 0  EYPC9Y08.doc  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...
# 1  N3LTSU3O.pdf  25-50-44-46-2D carpenters 25 landed strait dis...
# 2  D3D3WC9W.doc  D0-CF-11-E0-A1-B1-1A-E1 union 24 declined impo...
# 3  QCSW62YS.doc  D0-CF-11-E0-A1-B1-1A-E1 becoming period begin ...
# 4  AU75JV6U.jpg                                              FF-D8

# %%
#re visualize
display(df.shape)
display(df.head())
display(df.tail())
# Out:
# (445581, 6)
#                          id                date     user       pc  \
# 0  {L9G8-J9QE34VM-2834VDPB} 2010-01-02 07:23:14  MOH0273  PC-6699
# 1  {H0W6-L4FG38XG-9897XTEN} 2010-01-02 07:26:19  MOH0273  PC-6699
# 2  {M3Z0-O2KK89OX-5716MBIM} 2010-01-02 08:12:03  HPH0075  PC-2417
# 3  {E1I4-S4QS61TG-3652YHKR} 2010-01-02 08:17:00  HPH0075  PC-2417
# 4  {D4R7-E7JL45UX-0067XALT} 2010-01-02 08:24:57  HSB0196  PC-8001
#
#        filename                                            content
# 0  EYPC9Y08.doc  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...
# 1  N3LTSU3O.pdf  25-50-44-46-2D carpenters 25 landed strait dis...
# 2  D3D3WC9W.doc  D0-CF-11-E0-A1-B1-1A-E1 union 24 declined impo...
# 3  QCSW62YS.doc  D0-CF-11-E0-A1-B1-1A-E1 becoming period begin ...
# 4  AU75JV6U.jpg                                              FF-D8
#                               id                date     user       pc  \
# 445576  {J2Q8-Z4UX02QT-2675RTJI} 2011-05-16 23:22:31  IBB0359  PC-3620
# ...

# %%
df1 = df.copy()

# %%
df1['year'] = df1['date'].dt.year

# %%
display(df1.shape)
display(df1.head())
display(df1.tail())
# Out:
# (445581, 7)
#                          id                date     user       pc  \
# 0  {L9G8-J9QE34VM-2834VDPB} 2010-01-02 07:23:14  MOH0273  PC-6699
# 1  {H0W6-L4FG38XG-9897XTEN} 2010-01-02 07:26:19  MOH0273  PC-6699
# 2  {M3Z0-O2KK89OX-5716MBIM} 2010-01-02 08:12:03  HPH0075  PC-2417
# 3  {E1I4-S4QS61TG-3652YHKR} 2010-01-02 08:17:00  HPH0075  PC-2417
# 4  {D4R7-E7JL45UX-0067XALT} 2010-01-02 08:24:57  HSB0196  PC-8001
#
#        filename                                            content  year
# 0  EYPC9Y08.doc  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...  2010
# 1  N3LTSU3O.pdf  25-50-44-46-2D carpenters 25 landed strait dis...  2010
# 2  D3D3WC9W.doc  D0-CF-11-E0-A1-B1-1A-E1 union 24 declined impo...  2010
# 3  QCSW62YS.doc  D0-CF-11-E0-A1-B1-1A-E1 becoming period begin ...  2010
# 4  AU75JV6U.jpg                                              FF-D8  2010
#                               id                date     user       pc  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445581 entries, 0 to 445580
# Data columns (total 7 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        445581 non-null  object
#  1   date      445581 non-null  datetime64[ns]
#  2   user      445581 non-null  object
#  3   pc        445581 non-null  object
#  4   filename  445581 non-null  object
#  5   content   445581 non-null  object
#  6   year      445581 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 23.8+ MB

# %%
df1.year.unique()
# Out:
# array([2010, 2011])

# %%
new_df = df1[df1['date'].dt.year == 2010]

# %%
display(new_df.shape)
display(new_df.head())
display(new_df.tail())
# Out:
# (334459, 7)
#                          id                date     user       pc  \
# 0  {L9G8-J9QE34VM-2834VDPB} 2010-01-02 07:23:14  MOH0273  PC-6699
# 1  {H0W6-L4FG38XG-9897XTEN} 2010-01-02 07:26:19  MOH0273  PC-6699
# 2  {M3Z0-O2KK89OX-5716MBIM} 2010-01-02 08:12:03  HPH0075  PC-2417
# 3  {E1I4-S4QS61TG-3652YHKR} 2010-01-02 08:17:00  HPH0075  PC-2417
# 4  {D4R7-E7JL45UX-0067XALT} 2010-01-02 08:24:57  HSB0196  PC-8001
#
#        filename                                            content  year
# 0  EYPC9Y08.doc  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...  2010
# 1  N3LTSU3O.pdf  25-50-44-46-2D carpenters 25 landed strait dis...  2010
# 2  D3D3WC9W.doc  D0-CF-11-E0-A1-B1-1A-E1 union 24 declined impo...  2010
# 3  QCSW62YS.doc  D0-CF-11-E0-A1-B1-1A-E1 becoming period begin ...  2010
# 4  AU75JV6U.jpg                                              FF-D8  2010
#                               id                date     user       pc  \
# ...

# %%
del new_df['id']
del new_df['year']

# %%
#export new data frame
um.exportFile(new_df,'file')
# Out:
# Exporting file_copy.csv is Done !

# %% [markdown]
# # New Instance

# %%
from Modules import modules as md
from Modules import usermodules as um
import pandas as pd

# %%
df1 = md.ReadDataset('file_copy')

# %%
df1.head()
# Out:
#                   date     user       pc      filename  \
# 0  2010-01-02 07:23:14  MOH0273  PC-6699  EYPC9Y08.doc
# 1  2010-01-02 07:26:19  MOH0273  PC-6699  N3LTSU3O.pdf
# 2  2010-01-02 08:12:03  HPH0075  PC-2417  D3D3WC9W.doc
# 3  2010-01-02 08:17:00  HPH0075  PC-2417  QCSW62YS.doc
# 4  2010-01-02 08:24:57  HSB0196  PC-8001  AU75JV6U.jpg
#
#                                              content
# 0  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...
# 1  25-50-44-46-2D carpenters 25 landed strait dis...
# 2  D0-CF-11-E0-A1-B1-1A-E1 union 24 declined impo...
# 3  D0-CF-11-E0-A1-B1-1A-E1 becoming period begin ...
# 4                                              FF-D8
