# %%
import sys
sys.path.append('../Modules/')
import modules as md
import usermodules as um
import pandas as pd

# %%
logon = md.ReadDataset('logon_copy')
display(logon.head())
display(logon.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-4a5f9fd47536> in <module>
# ----> 1 logon = md.ReadDataset('logon_copy')
#       2 display(logon.head())
#       3 display(logon.shape)
#
# ~/Project Work/Insider-Threat-Detection-using-ML/Notebook/Modules/modules.py in ReadDataset(filename)
#       4 def ReadDataset(filename):
#       5     '''Path ===> ../Dataset/'''
# ----> 6     df = pd.read_csv(r'../../Dataset/'+filename+'.csv')
#       7     return df
#       8
#
# ~/.local/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
role = md.ReadDataset('user_role_copy')
role = role.rename(columns={"user_id":"user"})
display(role.head())
display(role.shape)
# Out:
#              employee_name     user                             email  \
# 0         Calvin Edan Love  CEL0561         Calvin.Edan.Love@dtaa.com
# 1  Christine Reagan Deleon  CRD0624  Christine.Reagan.Deleon@dtaa.com
# 2    Jade Felicia Caldwell  JFC0557    Jade.Felicia.Caldwell@dtaa.com
# 3   Aquila Stewart Dejesus  ASD0577   Aquila.Stewart.Dejesus@dtaa.com
# 4        Micah Abdul Rojas  MAR0955        Micah.Abdul.Rojas@dtaa.com
#
#                    role              department
# 0    ComputerProgrammer  2 - SoftwareManagement
# 1              Salesman               2 - Sales
# 2      SoftwareEngineer  2 - SoftwareManagement
# 3  ProductionLineWorker            3 - Assembly
# 4  ProductionLineWorker            3 - Assembly
# (11449, 5)

# %%
df = pd.merge(logon,role,on='user')
display(df.head())
display(df.shape)
# Out:
#                   date     user       pc activity      employee_name  \
# 0  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  Nissim Gil French
# 1  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  Nissim Gil French
# 2  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  Nissim Gil French
# 3  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  Nissim Gil French
# 4  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  Nissim Gil French
#
#                         email              role             department
# 0  Nissim.Gil.French@dtaa.com  FinancialAnalyst  3 - FinancialPlanning
# 1  Nissim.Gil.French@dtaa.com  FinancialAnalyst  3 - FinancialPlanning
# 2  Nissim.Gil.French@dtaa.com  FinancialAnalyst  3 - FinancialPlanning
# 3  Nissim.Gil.French@dtaa.com  FinancialAnalyst  3 - FinancialPlanning
# 4  Nissim.Gil.French@dtaa.com  FinancialAnalyst  3 - FinancialPlanning
# (7476706, 8)

# %%
df.isna().sum()
# Out:
# date                 0
# user                 0
# pc                   0
# activity             0
# employee_name        0
# email                0
# role                 0
# department       98244
# dtype: int64

# %%
df[df['department'].isnull()].index.tolist()
# Out:
# [1348120,
#  1348121,
#  1348122,
#  1348123,
#  1348124,
#  1348125,
#  1348126,
#  1348127,
#  1348128,
#  1348129,
#  1348130,
#  1348131,
#  1348132,
#  1348133,
#  1348134,
#  1348135,
#  1348136,
#  1348137,
#  1348138,
#  1348139,
#  1348140,
#  1348141,
#  1348142,
#  1348143,
#  1348144,
#  1348145,
#  1348146,
#  1348147,
#  1348148,
#  1348149,
#  1348150,
#  1348151,
#  1348152,
#  1348153,
#  1348154,
#  1348155,
#  1348156,
#  1348157,
#  1348158,
#  1348159,
#  1348160,
#  1348161,
#  1348162,
#  1348163,
#  1348164,
#  1348165,
#  1348166,
#  1348167,
#  1348168,
#  1348169,
#  1348170,
#  1348171,
#  1348172,
#  1348173,
#  1348174,
#  1348175,
#  1348176,
#  1348177,
#  1348178,
#  1348179,
#  1348180,
#  1348181,
#  1348182,
#  1348183,
#  1348184,
#  1348185,
#  1348186,
#  1348187,
#  1348188,
#  1348189,
#  1348190,
#  1348191,
#  1348192,
#  1348193,
#  1348194,
#  1348195,
#  1348196,
#  1348197,
#  1348198,
#  1348199,
#  1348200,
#  1348201,
#  1348202,
# ...

# %%
df.iloc[1348120]
# Out:
# date                   2010-01-04 06:45:00
# user                               KBP0008
# pc                                 PC-3851
# activity                             Logon
# employee_name             Kirby Bo Pollard
# email            Kirby.Bo.Pollard@dtaa.com
# role                         VicePresident
# department                             NaN
# Name: 1348120, dtype: object

# %%
try:
    df.loc[df['logon']=='KBP0008']
except:
    print('Not Found')
# Out:
# Not Found

# %%
df1 = df.dropna()

# %%
df1.isna().sum()
# Out:
# date             0
# user             0
# pc               0
# activity         0
# employee_name    0
# email            0
# role             0
# department       0
# dtype: int64

# %%
df1.head()
# Out:
#                   date     user       pc activity      employee_name  \
# 0  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  Nissim Gil French
# 1  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  Nissim Gil French
# 2  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  Nissim Gil French
# 3  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  Nissim Gil French
# 4  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  Nissim Gil French
#
#                         email              role             department
# 0  Nissim.Gil.French@dtaa.com  FinancialAnalyst  3 - FinancialPlanning
# 1  Nissim.Gil.French@dtaa.com  FinancialAnalyst  3 - FinancialPlanning
# 2  Nissim.Gil.French@dtaa.com  FinancialAnalyst  3 - FinancialPlanning
# 3  Nissim.Gil.French@dtaa.com  FinancialAnalyst  3 - FinancialPlanning
# 4  Nissim.Gil.French@dtaa.com  FinancialAnalyst  3 - FinancialPlanning

# %%
df2 = df1.copy()

# %%
df2['department'] = df2['department'].str.split(" - ",n=1,expand=True)[1]

# %%
df2.head()
# Out:
#                   date     user       pc activity      employee_name  \
# 0  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  Nissim Gil French
# 1  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  Nissim Gil French
# 2  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  Nissim Gil French
# 3  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  Nissim Gil French
# 4  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  Nissim Gil French
#
#                         email              role         department
# 0  Nissim.Gil.French@dtaa.com  FinancialAnalyst  FinancialPlanning
# 1  Nissim.Gil.French@dtaa.com  FinancialAnalyst  FinancialPlanning
# 2  Nissim.Gil.French@dtaa.com  FinancialAnalyst  FinancialPlanning
# 3  Nissim.Gil.French@dtaa.com  FinancialAnalyst  FinancialPlanning
# 4  Nissim.Gil.French@dtaa.com  FinancialAnalyst  FinancialPlanning

# %%
df2.tail()
# Out:
#                         date     user       pc activity     employee_name  \
# 7476701  2010-12-30 18:10:00  RHY0079  PC-1896   Logoff  Rose Hanae Yates
# 7476702  2010-12-30 18:10:00  RHY0079  PC-1896   Logoff  Rose Hanae Yates
# 7476703  2010-12-30 18:10:00  RHY0079  PC-1896   Logoff  Rose Hanae Yates
# 7476704  2010-12-30 18:10:00  RHY0079  PC-1896   Logoff  Rose Hanae Yates
# 7476705  2010-12-30 18:10:00  RHY0079  PC-1896   Logoff  Rose Hanae Yates
#
#                              email           role   department
# 7476701  Rose.Hanae.Yates@dtaa.com  ChiefEngineer  Engineering
# 7476702  Rose.Hanae.Yates@dtaa.com  ChiefEngineer  Engineering
# 7476703  Rose.Hanae.Yates@dtaa.com  ChiefEngineer  Engineering
# 7476704  Rose.Hanae.Yates@dtaa.com  ChiefEngineer  Engineering
# 7476705  Rose.Hanae.Yates@dtaa.com  ChiefEngineer  Engineering

# %%
df2.shape
# Out:
# (7378462, 8)

# %%
df3 =df2.copy()

# %%
df4 = df3.drop_duplicates(keep='last')

# %%
df4.duplicated().sum()
# Out:
# 0

# %%
df4.head()
# Out:
#                    date     user       pc activity      employee_name  \
# 11  2010-01-02 06:49:00  NGF0157  PC-6056    Logon  Nissim Gil French
# 23  2010-01-02 09:55:53  NGF0157  PC-6056    Logon  Nissim Gil French
# 35  2010-01-02 17:05:00  NGF0157  PC-6056   Logoff  Nissim Gil French
# 47  2010-01-04 07:01:00  NGF0157  PC-6056    Logon  Nissim Gil French
# 59  2010-01-04 11:25:51  NGF0157  PC-6056    Logon  Nissim Gil French
#
#                          email              role         department
# 11  Nissim.Gil.French@dtaa.com  FinancialAnalyst  FinancialPlanning
# 23  Nissim.Gil.French@dtaa.com  FinancialAnalyst  FinancialPlanning
# 35  Nissim.Gil.French@dtaa.com  FinancialAnalyst  FinancialPlanning
# 47  Nissim.Gil.French@dtaa.com  FinancialAnalyst  FinancialPlanning
# 59  Nissim.Gil.French@dtaa.com  FinancialAnalyst  FinancialPlanning

# %%
df5 =df4.sort_values('date',ignore_index=True)

# %%
df5.head()
# Out:
#                   date     user       pc activity          employee_name  \
# 0  2010-01-02 06:49:00  NGF0157  PC-6056    Logon      Nissim Gil French
# 1  2010-01-02 06:50:00  LRR0148  PC-4275    Logon  Libby Rosalyn Richard
# 2  2010-01-02 06:53:04  LRR0148  PC-4124    Logon  Libby Rosalyn Richard
# 3  2010-01-02 07:00:00  IRM0931  PC-7188    Logon  Ignatius Reese Morton
# 4  2010-01-02 07:00:00  MOH0273  PC-6699    Logon  Macaulay Otto Hopkins
#
#                             email                role          department
# 0      Nissim.Gil.French@dtaa.com    FinancialAnalyst   FinancialPlanning
# 1  Libby.Rosalyn.Richard@dtaa.com             Manager   FinancialPlanning
# 2  Libby.Rosalyn.Richard@dtaa.com             Manager   FinancialPlanning
# 3  Ignatius.Reese.Morton@dtaa.com  ComputerProgrammer  SoftwareManagement
# 4  Macaulay.Otto.Hopkins@dtaa.com    HardwareEngineer         Engineering

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 632424 entries, 0 to 632423
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   date           632424 non-null  object
#  1   user           632424 non-null  object
#  2   pc             632424 non-null  object
#  3   activity       632424 non-null  object
#  4   employee_name  632424 non-null  object
#  5   email          632424 non-null  object
#  6   role           632424 non-null  object
#  7   department     632424 non-null  object
# dtypes: object(8)
# memory usage: 38.6+ MB

# %%
df5.shape
# Out:
# (632424, 8)

# %%
df5.head()
# Out:
#                   date     user       pc activity          employee_name  \
# 0  2010-01-02 06:49:00  NGF0157  PC-6056    Logon      Nissim Gil French
# 1  2010-01-02 06:50:00  LRR0148  PC-4275    Logon  Libby Rosalyn Richard
# 2  2010-01-02 06:53:04  LRR0148  PC-4124    Logon  Libby Rosalyn Richard
# 3  2010-01-02 07:00:00  IRM0931  PC-7188    Logon  Ignatius Reese Morton
# 4  2010-01-02 07:00:00  MOH0273  PC-6699    Logon  Macaulay Otto Hopkins
#
#                             email                role          department
# 0      Nissim.Gil.French@dtaa.com    FinancialAnalyst   FinancialPlanning
# 1  Libby.Rosalyn.Richard@dtaa.com             Manager   FinancialPlanning
# 2  Libby.Rosalyn.Richard@dtaa.com             Manager   FinancialPlanning
# 3  Ignatius.Reese.Morton@dtaa.com  ComputerProgrammer  SoftwareManagement
# 4  Macaulay.Otto.Hopkins@dtaa.com    HardwareEngineer         Engineering

# %%
df5.tail()
# Out:
#                        date     user       pc activity  \
# 632419  2010-12-31 19:27:00  JDC0030  PC-0246   Logoff
# 632420  2010-12-31 19:28:00  PTH0830  PC-8118   Logoff
# 632421  2010-12-31 19:29:00  IBS0836  PC-6382   Logoff
# 632422  2010-12-31 23:25:25  AJF0370  PC-0514    Logon
# 632423  2010-12-31 23:44:05  AJF0370  PC-0514   Logoff
#
#                   employee_name                             email  \
# 632419     Jenna Darrel Charles     Jenna.Darrel.Charles@dtaa.com
# 632420        Peter Tad Hartman        Peter.Tad.Hartman@dtaa.com
# 632421  Isadora Blaine Shepherd  Isadora.Blaine.Shepherd@dtaa.com
# 632422        Arthur John Floyd        Arthur.John.Floyd@dtaa.com
# 632423        Arthur John Floyd        Arthur.John.Floyd@dtaa.com
#
#                            role department
# 632419  AdministrativeAssistant   Security
# 632420     ProductionLineWorker   Assembly
# 632421     ProductionLineWorker   Assembly
# 632422                  ITAdmin   Security
# ...

# %%
um.exportFile(df5,'logon_role')
# Out:
# Exporting logon_role_copy.csv is Done !

# %% [markdown]
# # Verify

# %%
df = pd.read_csv('../../Dataset/logon_role_copy.csv')
df.head()
# Out:
#                   date     user       pc activity          employee_name  \
# 0  2010-01-02 06:49:00  NGF0157  PC-6056    Logon      Nissim Gil French
# 1  2010-01-02 06:50:00  LRR0148  PC-4275    Logon  Libby Rosalyn Richard
# 2  2010-01-02 06:53:04  LRR0148  PC-4124    Logon  Libby Rosalyn Richard
# 3  2010-01-02 07:00:00  IRM0931  PC-7188    Logon  Ignatius Reese Morton
# 4  2010-01-02 07:00:00  MOH0273  PC-6699    Logon  Macaulay Otto Hopkins
#
#                             email                role          department
# 0      Nissim.Gil.French@dtaa.com    FinancialAnalyst   FinancialPlanning
# 1  Libby.Rosalyn.Richard@dtaa.com             Manager   FinancialPlanning
# 2  Libby.Rosalyn.Richard@dtaa.com             Manager   FinancialPlanning
# 3  Ignatius.Reese.Morton@dtaa.com  ComputerProgrammer  SoftwareManagement
# 4  Macaulay.Otto.Hopkins@dtaa.com    HardwareEngineer         Engineering
