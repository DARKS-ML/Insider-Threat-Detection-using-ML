# %%
import sys
sys.path.append('../Modules/')
import modules as md
import usermodules as um
import pandas as pd

# %%
file = md.ReadDataset('file_copy')
display(file.head())
display(file.shape)
# Out:
#                   date     user       pc      filename  \
# 0  2010-01-02 07:23:14  MOH0273  PC-6699  EYPC9Y08.doc
# 1  2010-01-02 07:26:19  MOH0273  PC-6699  N3LTSU3O.pdf
# 2  2010-01-02 08:12:03  HPH0075  PC-2417  D3D3WC9W.doc
# 3  2010-01-02 08:17:00  HPH0075  PC-2417  QCSW62YS.doc
# 4  2010-01-02 08:24:57  HSB0196  PC-8001  AU75JV6U.jpg
#
#                                              content
# 0  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...
# 1  25-50-44-46-2D carpenters 25 landed strait dis...
# 2  D0-CF-11-E0-A1-B1-1A-E1 union 24 declined impo...
# 3  D0-CF-11-E0-A1-B1-1A-E1 becoming period begin ...
# 4                                              FF-D8
# (334459, 5)

# %%
role = md.ReadDataset('user_role_copy')
role = role.rename(columns={"user_id":"user"})
display(role.head())
display(role.shape)
# Out:
#              employee_name     user                             email  \
# 0         Calvin Edan Love  CEL0561         Calvin.Edan.Love@dtaa.com
# 1  Christine Reagan Deleon  CRD0624  Christine.Reagan.Deleon@dtaa.com
# 2    Jade Felicia Caldwell  JFC0557    Jade.Felicia.Caldwell@dtaa.com
# 3   Aquila Stewart Dejesus  ASD0577   Aquila.Stewart.Dejesus@dtaa.com
# 4        Micah Abdul Rojas  MAR0955        Micah.Abdul.Rojas@dtaa.com
#
#                    role              department
# 0    ComputerProgrammer  2 - SoftwareManagement
# 1              Salesman               2 - Sales
# 2      SoftwareEngineer  2 - SoftwareManagement
# 3  ProductionLineWorker            3 - Assembly
# 4  ProductionLineWorker            3 - Assembly
# (11449, 5)

# %%
df = pd.merge(file,role,on='user')
display(df.head())
display(df.shape)
# Out:
#                   date     user       pc      filename  \
# 0  2010-01-02 07:23:14  MOH0273  PC-6699  EYPC9Y08.doc
# 1  2010-01-02 07:23:14  MOH0273  PC-6699  EYPC9Y08.doc
# 2  2010-01-02 07:23:14  MOH0273  PC-6699  EYPC9Y08.doc
# 3  2010-01-02 07:23:14  MOH0273  PC-6699  EYPC9Y08.doc
# 4  2010-01-02 07:23:14  MOH0273  PC-6699  EYPC9Y08.doc
#
#                                              content          employee_name  \
# 0  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...  Macaulay Otto Hopkins
# 1  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...  Macaulay Otto Hopkins
# 2  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...  Macaulay Otto Hopkins
# 3  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...  Macaulay Otto Hopkins
# 4  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...  Macaulay Otto Hopkins
#
#                             email              role       department
# 0  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  3 - Engineering
# 1  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  3 - Engineering
# 2  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  3 - Engineering
# 3  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  3 - Engineering
# 4  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  3 - Engineering
# (3881935, 9)

# %%
df.isna().sum()
# Out:
# date                 0
# user                 0
# pc                   0
# filename             0
# content              0
# employee_name        0
# email                0
# role                 0
# department       26136
# dtype: int64

# %%
df[df['department'].isnull()].index.tolist()
# Out:
# [1902246,
#  1902247,
#  1902248,
#  1902249,
#  1902250,
#  1902251,
#  1902252,
#  1902253,
#  1902254,
#  1902255,
#  1902256,
#  1902257,
#  1902258,
#  1902259,
#  1902260,
#  1902261,
#  1902262,
#  1902263,
#  1902264,
#  1902265,
#  1902266,
#  1902267,
#  1902268,
#  1902269,
#  1902270,
#  1902271,
#  1902272,
#  1902273,
#  1902274,
#  1902275,
#  1902276,
#  1902277,
#  1902278,
#  1902279,
#  1902280,
#  1902281,
#  1902282,
#  1902283,
#  1902284,
#  1902285,
#  1902286,
#  1902287,
#  1902288,
#  1902289,
#  1902290,
#  1902291,
#  1902292,
#  1902293,
#  1902294,
#  1902295,
#  1902916,
#  1902917,
#  1902918,
#  1902919,
#  1902920,
#  1902921,
#  1902922,
#  1902923,
#  1902924,
#  1902925,
#  1902926,
#  1902927,
#  1902928,
#  1902929,
#  1902930,
#  1902931,
#  1902932,
#  1902933,
#  1902934,
#  1902935,
#  1902936,
#  1902937,
#  1902938,
#  1902939,
#  1902940,
#  1902941,
#  1902942,
#  1902943,
#  1902944,
#  1902945,
#  1902946,
#  1902947,
#  1902948,
#  1902949,
#  1902950,
#  1902951,
#  1902952,
#  1902953,
#  1902954,
#  1902955,
#  1902956,
#  1902957,
#  1902958,
#  1902959,
#  1902960,
#  1902961,
#  1902962,
#  1902963,
#  1902964,
#  1902965,
#  1902966,
#  1902967,
#  1902968,
#  1902969,
#  1902970,
#  1902971,
#  1902972,
#  1902973,
#  1902974,
#  1902975,
#  1902976,
#  1902977,
#  1902978,
#  1902979,
#  1902980,
#  1902981,
#  1902982,
#  1902983,
#  1902984,
#  1902985,
#  1902986,
#  1902987,
#  1902988,
#  1902989,
#  1902990,
#  1902991,
#  1902992,
#  1902993,
#  1902994,
#  1902995,
#  1902996,
#  1902997,
#  1902998,
#  1902999,
#  1903000,
#  1903001,
#  1903002,
#  1903003,
#  1903004,
#  1903005,
#  1903006,
#  1903007,
#  1903008,
#  1903009,
#  1903010,
#  1903011,
#  1903012,
#  1903013,
#  1903014,
#  1903015,
#  1903016,
#  1903017,
#  1903018,
#  1903019,
#  1903020,
#  1903021,
#  1903022,
#  1903023,
#  1903024,
#  1903025,
#  1903026,
#  1903027,
#  1903028,
#  1903029,
#  1903030,
#  1903031,
#  1903032,
#  1903033,
#  1903034,
#  1903035,
#  1903036,
#  1903037,
#  1903038,
#  1903039,
#  1903040,
#  1903041,
#  1903042,
#  1903043,
#  1903044,
#  1903045,
#  1903046,
#  1903047,
#  1903048,
#  1903049,
#  1903050,
#  1903051,
#  1903052,
#  1903053,
#  1903054,
#  1903055,
#  1903056,
#  1903057,
#  1903058,
#  1903059,
#  1903060,
#  1903061,
#  1903062,
#  1903063,
#  1903064,
#  1903065,
#  1903066,
#  1903067,
#  1903068,
#  1903069,
#  1903070,
#  1903071,
#  1903072,
#  1903073,
#  1903074,
#  1903075,
#  1903076,
#  1903077,
#  1903078,
#  1903079,
#  1903080,
#  1903081,
#  1903082,
#  1903083,
#  1903084,
#  1903085,
#  1903086,
#  1903087,
#  1903088,
#  1903089,
#  1903090,
#  1903091,
#  1903092,
#  1903093,
#  1903094,
#  1903095,
#  1903096,
#  1903097,
#  1903098,
#  1903099,
#  1903100,
#  1903101,
#  1903102,
#  1903103,
#  1903104,
#  1903105,
#  1903106,
#  1903107,
#  1903108,
#  1903109,
#  1903110,
#  1903111,
#  1903112,
#  1903113,
#  1903114,
#  1903115,
#  1903116,
#  1903117,
#  1903118,
#  1903119,
#  1903120,
#  1903121,
#  1903122,
#  1903123,
#  1903124,
#  1903125,
#  1903126,
#  1903127,
#  1903128,
#  1903129,
#  1903130,
#  1903131,
#  1903132,
#  1903133,
#  1903134,
#  1903135,
#  1903136,
#  1903137,
#  1903138,
#  1903139,
#  1903140,
#  1903141,
#  1903142,
#  1903143,
#  1903144,
#  1903145,
#  1903146,
#  1903147,
#  1903148,
#  1903149,
#  1903150,
#  1903151,
#  1903152,
#  1903153,
#  1903154,
#  1903155,
#  1903156,
#  1903157,
#  1903158,
#  1903159,
#  1903160,
#  1903161,
#  1903162,
#  1903163,
#  1903164,
#  1903165,
#  1903166,
#  1903167,
#  1903168,
#  1903169,
#  1903170,
#  1903171,
#  1903172,
#  1903173,
#  1903174,
#  1903175,
#  1903176,
#  1903177,
#  1903178,
#  1903179,
#  1903180,
#  1903181,
#  1903182,
#  1903183,
#  1903184,
#  1903185,
#  1903186,
#  1903187,
#  1903188,
#  1903189,
#  1903190,
#  1903191,
#  1903192,
#  1903193,
#  1903194,
#  1903195,
#  1903196,
#  1903197,
#  1903198,
#  1903199,
#  1903200,
#  1903201,
#  1903202,
#  1903203,
#  1903204,
#  1903205,
#  1903206,
#  1903207,
#  1903208,
#  1903209,
#  1903210,
#  1903211,
#  1903212,
#  1903213,
#  1903214,
#  1903215,
#  1903216,
#  1903217,
#  1903218,
#  1903219,
#  1903220,
#  1903221,
#  1903222,
#  1903223,
#  1903224,
#  1903225,
#  1903226,
#  1903227,
#  1903228,
#  1903229,
#  1903230,
#  1903231,
#  1903232,
#  1903233,
#  1903234,
#  1903235,
#  1903236,
#  1903237,
#  1903238,
#  1903239,
#  1903240,
#  1903241,
#  1903242,
#  1903243,
#  1903244,
#  1903245,
#  ...]

# %%
try:
    df.loc[df['logon']=='KBP0008']
except:
    print('Not Found')
# Out:
# Not Found

# %%
df1 = df.dropna()

# %%
df1.isna().sum()
# Out:
# date             0
# user             0
# pc               0
# filename         0
# content          0
# employee_name    0
# email            0
# role             0
# department       0
# dtype: int64

# %%
df1.head()
# Out:
#                   date     user       pc      filename  \
# 0  2010-01-02 07:23:14  MOH0273  PC-6699  EYPC9Y08.doc
# 1  2010-01-02 07:23:14  MOH0273  PC-6699  EYPC9Y08.doc
# 2  2010-01-02 07:23:14  MOH0273  PC-6699  EYPC9Y08.doc
# 3  2010-01-02 07:23:14  MOH0273  PC-6699  EYPC9Y08.doc
# 4  2010-01-02 07:23:14  MOH0273  PC-6699  EYPC9Y08.doc
#
#                                              content          employee_name  \
# 0  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...  Macaulay Otto Hopkins
# 1  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...  Macaulay Otto Hopkins
# 2  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...  Macaulay Otto Hopkins
# 3  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...  Macaulay Otto Hopkins
# 4  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...  Macaulay Otto Hopkins
#
#                             email              role       department
# 0  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  3 - Engineering
# 1  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  3 - Engineering
# 2  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  3 - Engineering
# 3  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  3 - Engineering
# 4  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  3 - Engineering

# %%
df2 = df1.copy()

# %%
df2['department'] = df2['department'].str.split(" - ",n=1,expand=True)[1]

# %%
df3 =df2.copy()

# %%
df4 = df3.drop_duplicates(keep='last')

# %%
df4.duplicated().sum()
# Out:
# 0

# %%
df4.head()
# Out:
#                    date     user       pc      filename  \
# 11  2010-01-02 07:23:14  MOH0273  PC-6699  EYPC9Y08.doc
# 23  2010-01-02 07:26:19  MOH0273  PC-6699  N3LTSU3O.pdf
# 35  2010-01-02 08:28:08  MOH0273  PC-6699  JS09VZOJ.doc
# 47  2010-01-02 08:28:24  MOH0273  PC-6699  LX0I6B1U.pdf
# 59  2010-01-02 09:14:38  MOH0273  PC-6699  TMF79YY1.doc
#
#                                               content          employee_name  \
# 11  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...  Macaulay Otto Hopkins
# 23  25-50-44-46-2D carpenters 25 landed strait dis...  Macaulay Otto Hopkins
# 35  D0-CF-11-E0-A1-B1-1A-E1 yet chamberlain own co...  Macaulay Otto Hopkins
# 47  25-50-44-46-2D found british conflict close th...  Macaulay Otto Hopkins
# 59  D0-CF-11-E0-A1-B1-1A-E1 hastily apparently tho...  Macaulay Otto Hopkins
#
#                              email              role   department
# 11  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  Engineering
# 23  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  Engineering
# 35  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  Engineering
# 47  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  Engineering
# 59  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  Engineering

# %%
df5 =df4.sort_values('date',ignore_index=True)

# %%
df5.head()
# Out:
#                   date     user       pc      filename  \
# 0  2010-01-02 07:23:14  MOH0273  PC-6699  EYPC9Y08.doc
# 1  2010-01-02 07:26:19  MOH0273  PC-6699  N3LTSU3O.pdf
# 2  2010-01-02 08:12:03  HPH0075  PC-2417  D3D3WC9W.doc
# 3  2010-01-02 08:17:00  HPH0075  PC-2417  QCSW62YS.doc
# 4  2010-01-02 08:24:57  HSB0196  PC-8001  AU75JV6U.jpg
#
#                                              content          employee_name  \
# 0  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...  Macaulay Otto Hopkins
# 1  25-50-44-46-2D carpenters 25 landed strait dis...  Macaulay Otto Hopkins
# 2  D0-CF-11-E0-A1-B1-1A-E1 union 24 declined impo...    Harper Price Harris
# 3  D0-CF-11-E0-A1-B1-1A-E1 becoming period begin ...    Harper Price Harris
# 4                                              FF-D8     Hadley Sonya Bowen
#
#                             email              role   department
# 0  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  Engineering
# 1  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  Engineering
# 2    Harper.Price.Harris@dtaa.com     ChiefEngineer  Engineering
# 3    Harper.Price.Harris@dtaa.com     ChiefEngineer  Engineering
# 4     Hadley.Sonya.Bowen@dtaa.com   PurchasingClerk   Purchasing

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332281 entries, 0 to 332280
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   date           332281 non-null  object
#  1   user           332281 non-null  object
#  2   pc             332281 non-null  object
#  3   filename       332281 non-null  object
#  4   content        332281 non-null  object
#  5   employee_name  332281 non-null  object
#  6   email          332281 non-null  object
#  7   role           332281 non-null  object
#  8   department     332281 non-null  object
# dtypes: object(9)
# memory usage: 22.8+ MB

# %%
df5.shape
# Out:
# (332281, 9)

# %%
df5.head()
# Out:
#                   date     user       pc      filename  \
# 0  2010-01-02 07:23:14  MOH0273  PC-6699  EYPC9Y08.doc
# 1  2010-01-02 07:26:19  MOH0273  PC-6699  N3LTSU3O.pdf
# 2  2010-01-02 08:12:03  HPH0075  PC-2417  D3D3WC9W.doc
# 3  2010-01-02 08:17:00  HPH0075  PC-2417  QCSW62YS.doc
# 4  2010-01-02 08:24:57  HSB0196  PC-8001  AU75JV6U.jpg
#
#                                              content          employee_name  \
# 0  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...  Macaulay Otto Hopkins
# 1  25-50-44-46-2D carpenters 25 landed strait dis...  Macaulay Otto Hopkins
# 2  D0-CF-11-E0-A1-B1-1A-E1 union 24 declined impo...    Harper Price Harris
# 3  D0-CF-11-E0-A1-B1-1A-E1 becoming period begin ...    Harper Price Harris
# 4                                              FF-D8     Hadley Sonya Bowen
#
#                             email              role   department
# 0  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  Engineering
# 1  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  Engineering
# 2    Harper.Price.Harris@dtaa.com     ChiefEngineer  Engineering
# 3    Harper.Price.Harris@dtaa.com     ChiefEngineer  Engineering
# 4     Hadley.Sonya.Bowen@dtaa.com   PurchasingClerk   Purchasing

# %%
df5.tail()
# Out:
#                        date     user       pc      filename  \
# 332276  2010-12-31 17:26:12  HRB0351  PC-0697  6PYAU6YM.doc
# 332277  2010-12-31 17:26:50  HRB0351  PC-0697  8F6V1GIB.zip
# 332278  2010-12-31 17:27:17  HRB0351  PC-0697  L57EEEU4.pdf
# 332279  2010-12-31 18:54:05  AJF0370  PC-3978  REPRB3TE.txt
# 332280  2010-12-31 18:56:23  AJF0370  PC-3978  08APT2N5.pdf
#
#                                                   content  \
# 332276  D0-CF-11-E0-A1-B1-1A-E1 depth institution aver...
# 332277  50-4B-03-04-14 brought down short maximum enou...
# 332278  25-50-44-46-2D designated awarded superior sav...
# 332279  4B-53-4B-37 mammals fear us consequences conse...
# 332280  25-50-44-46-2D dcn strengthen muscular seemed ...
#
#                employee_name                          email           role  \
# 332276  Hadassah Riley Baker  Hadassah.Riley.Baker@dtaa.com  ChiefEngineer
# 332277  Hadassah Riley Baker  Hadassah.Riley.Baker@dtaa.com  ChiefEngineer
# 332278  Hadassah Riley Baker  Hadassah.Riley.Baker@dtaa.com  ChiefEngineer
# 332279     Arthur John Floyd     Arthur.John.Floyd@dtaa.com        ITAdmin
# 332280     Arthur John Floyd     Arthur.John.Floyd@dtaa.com        ITAdmin
#
#          department
# 332276  Engineering
# 332277  Engineering
# 332278  Engineering
# 332279     Security
# 332280     Security

# %%
um.exportFile(df5,'file_role')
# Out:
# Exporting role_file_copy.csv is Done !

# %% [markdown]
# # Verify

# %%
df = pd.read_csv('../../Dataset/file_copy.csv')
df.head()
# Out:
#                   date     user       pc      filename  \
# 0  2010-01-02 07:23:14  MOH0273  PC-6699  EYPC9Y08.doc
# 1  2010-01-02 07:26:19  MOH0273  PC-6699  N3LTSU3O.pdf
# 2  2010-01-02 08:12:03  HPH0075  PC-2417  D3D3WC9W.doc
# 3  2010-01-02 08:17:00  HPH0075  PC-2417  QCSW62YS.doc
# 4  2010-01-02 08:24:57  HSB0196  PC-8001  AU75JV6U.jpg
#
#                                              content          employee_name  \
# 0  D0-CF-11-E0-A1-B1-1A-E1 during difficulty over...  Macaulay Otto Hopkins
# 1  25-50-44-46-2D carpenters 25 landed strait dis...  Macaulay Otto Hopkins
# 2  D0-CF-11-E0-A1-B1-1A-E1 union 24 declined impo...    Harper Price Harris
# 3  D0-CF-11-E0-A1-B1-1A-E1 becoming period begin ...    Harper Price Harris
# 4                                              FF-D8     Hadley Sonya Bowen
#
#                             email              role   department
# 0  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  Engineering
# 1  Macaulay.Otto.Hopkins@dtaa.com  HardwareEngineer  Engineering
# 2    Harper.Price.Harris@dtaa.com     ChiefEngineer  Engineering
# 3    Harper.Price.Harris@dtaa.com     ChiefEngineer  Engineering
# 4     Hadley.Sonya.Bowen@dtaa.com   PurchasingClerk   Purchasing
