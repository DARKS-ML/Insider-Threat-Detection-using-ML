# %%
from Modules import modules as md
from Modules import usermodules as um
import pandas as pd

# %%
df1 = md.ReadDataset('r4.2/LDAP/2010-01')
df2 = md.ReadDataset('r4.2/LDAP/2010-02')
df3 = md.ReadDataset('r4.2/LDAP/2010-03')
df4 = md.ReadDataset('r4.2/LDAP/2010-04')
df5 = md.ReadDataset('r4.2/LDAP/2010-05')
df6 = md.ReadDataset('r4.2/LDAP/2010-06')
df7 = md.ReadDataset('r4.2/LDAP/2010-07')
df8 = md.ReadDataset('r4.2/LDAP/2010-08')
df9 = md.ReadDataset('r4.2/LDAP/2010-09')
df10 = md.ReadDataset('r4.2/LDAP/2010-10')
df11 = md.ReadDataset('r4.2/LDAP/2010-11')
df12 = md.ReadDataset('r4.2/LDAP/2010-12')

# %%
frames = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12]

# %%
df = pd.concat(frames)

# %%
display(df.shape)
display(df.head())
display(df.tail())
# Out:
# (11449, 9)
#              employee_name  user_id                             email  \
# 0         Calvin Edan Love  CEL0561         Calvin.Edan.Love@dtaa.com
# 1  Christine Reagan Deleon  CRD0624  Christine.Reagan.Deleon@dtaa.com
# 2    Jade Felicia Caldwell  JFC0557    Jade.Felicia.Caldwell@dtaa.com
# 3   Aquila Stewart Dejesus  ASD0577   Aquila.Stewart.Dejesus@dtaa.com
# 4        Micah Abdul Rojas  MAR0955        Micah.Abdul.Rojas@dtaa.com
#
#                    role  business_unit             functional_unit  \
# 0    ComputerProgrammer              1  2 - ResearchAndEngineering
# 1              Salesman              1       5 - SalesAndMarketing
# 2      SoftwareEngineer              1  2 - ResearchAndEngineering
# 3  ProductionLineWorker              1           3 - Manufacturing
# 4  ProductionLineWorker              1           3 - Manufacturing
#
#                department               team                  supervisor
# ...

# %%
df.columns.unique()
# Out:
# Index(['employee_name', 'user_id', 'email', 'role', 'business_unit',
#        'functional_unit', 'department', 'team', 'supervisor'],
#       dtype='object')

# %%
del df['business_unit']
del df['functional_unit']
del df['team']
del  df['supervisor']

# %%
display(df.shape)
display(df.head())
display(df.tail())
# Out:
# (11449, 5)
#              employee_name  user_id                             email  \
# 0         Calvin Edan Love  CEL0561         Calvin.Edan.Love@dtaa.com
# 1  Christine Reagan Deleon  CRD0624  Christine.Reagan.Deleon@dtaa.com
# 2    Jade Felicia Caldwell  JFC0557    Jade.Felicia.Caldwell@dtaa.com
# 3   Aquila Stewart Dejesus  ASD0577   Aquila.Stewart.Dejesus@dtaa.com
# 4        Micah Abdul Rojas  MAR0955        Micah.Abdul.Rojas@dtaa.com
#
#                    role              department
# 0    ComputerProgrammer  2 - SoftwareManagement
# 1              Salesman               2 - Sales
# 2      SoftwareEngineer  2 - SoftwareManagement
# 3  ProductionLineWorker            3 - Assembly
# 4  ProductionLineWorker            3 - Assembly
#                employee_name  user_id                             email  \
# 885        Dylan Tiger Terry  DTT0076        Dylan.Tiger.Terry@dtaa.com
# 886      Price Rashad Mullen  PRM0740      Price.Rashad.Mullen@dtaa.com
# ...

# %%
um.exportFile(df,'user_role')
# Out:
# Exporting user_role_copy.csv is Done !

# %% [markdown]
# # Verify

# %%
from Modules import modules as md
from Modules import usermodules as um
import pandas as pd

# %%
df1 = md.ReadDataset('user_role_copy')

# %%
df1.head()
# Out:
#              employee_name  user_id                             email  \
# 0         Calvin Edan Love  CEL0561         Calvin.Edan.Love@dtaa.com
# 1  Christine Reagan Deleon  CRD0624  Christine.Reagan.Deleon@dtaa.com
# 2    Jade Felicia Caldwell  JFC0557    Jade.Felicia.Caldwell@dtaa.com
# 3   Aquila Stewart Dejesus  ASD0577   Aquila.Stewart.Dejesus@dtaa.com
# 4        Micah Abdul Rojas  MAR0955        Micah.Abdul.Rojas@dtaa.com
#
#                    role              department
# 0    ComputerProgrammer  2 - SoftwareManagement
# 1              Salesman               2 - Sales
# 2      SoftwareEngineer  2 - SoftwareManagement
# 3  ProductionLineWorker            3 - Assembly
# 4  ProductionLineWorker            3 - Assembly
